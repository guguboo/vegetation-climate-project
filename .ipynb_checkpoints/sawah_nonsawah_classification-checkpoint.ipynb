# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from tslearn.metrics import dtw
from tslearn.utils import to_time_series
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import time
from datetime import datetime
import os

# %%
class SawahClassification_KNNDTW:
    def __init__(self,
                 filename, # nama file sawah
                 labeled_filename, # nama file pelabelan
                 folder_name = 'sawah_classification/',
                 evi = True, # EVI atau NDVI
                 random_state = 42
                ):
        self.labeled_filename = labeled_filename
        self.filename = "evi_" + filename if evi else filename
        self.kecamatan = filename.split(".")[0]
        self.evi = evi
        self.folder_name = folder_name
        self.best_params = {'acc': 0, 'dtw': None, 'k': None, 'year': None}
        self.best_model = None
        self.wilayah_df = None
        self.labeled_merged = None
        self.wilayah_not_labeled = None
        self.labeled_df = None
        self.X_sawah = None
        self.y_sawah = None
        self.random_state = random_state
        self.preprocess()
        
    def preprocess(self):
        start_time = time.time()
        wilayah_df = pd.read_csv(self.folder_name + self.filename).drop(".geo", axis=1)
        self.labeled_df = pd.read_csv(self.folder_name + self.labeled_filename).drop([".geo", "system:index"], axis=1)
        columns = wilayah_df.columns.tolist()
        renamed_columns = []
        
        for col in columns:
            colname = ""
            if "T48MYT" in col:
                colname = col.split("_")[3][:8]
            elif "LC08" in col:
                colname = col.split("_")[5]
            elif "LE07" in col:
                colname = col.split("_")[3]
            renamed_columns.append(colname)
        
        renamed_columns = renamed_columns[:-1]
        
        old_new_col = dict(zip(columns, renamed_columns))
        wilayah_df = wilayah_df.rename(columns=old_new_col)
        # print(wilayah_df)
        # menghapus kolom yg namanya duplikat
        wilayah_df = wilayah_df.loc[:, ~wilayah_df.columns.duplicated(keep='first')]
        
        # mengurutkan kolom berdasarkan urutan tanggalnya
        wilayah_df = wilayah_df.reindex(sorted(wilayah_df.columns), axis=1)
        
        cluster_id = wilayah_df['cluster_id']
        
        wilayah_df = wilayah_df.iloc[:, 1:-1].interpolate(axis=1)
        wilayah_df = wilayah_df.bfill(axis=1)
        wilayah_df = wilayah_df.ffill(axis=1)
        wilayah_df = pd.concat([wilayah_df, cluster_id], axis=1)

        
        self.wilayah_df = wilayah_df

        wilayah_labeled = wilayah_df[wilayah_df['cluster_id'].isin(self.labeled_df['cluster_id'])]
        self.wilayah_not_labeled = wilayah_df[~wilayah_df['cluster_id'].isin(self.labeled_df['cluster_id'])]
        print("Labeled data: " + str(wilayah_labeled.shape))
        print("Non-labeled data: " + str(self.wilayah_not_labeled.shape))

        self.labeled_merged = pd.merge(wilayah_labeled, self.labeled_df, on='cluster_id', how='left')
        self.X_sawah = self.labeled_merged.iloc[:, :-2]
        self.y_sawah = self.labeled_merged['label']
        print("--- Preprocessing done in %s seconds ---" % (time.time() - start_time))

    def tune(self, dtw_tuner = None, knn_tuner = None, date_tuner = None, output_file='tuning_results.txt'):
        '''
        dtw_tuner = {constraint: ['default', 'sakoe_chiba', 'itakura'], slope:[1, 2, 3, 4, 5], radius: [1,3,5,7]}
        knn_tuner = [3, 5, 7, 9, 11]
        date_tuner = {'start': [2011, 2012, 2013, 2014, 2015], 'year_time': [3, 5, 7, 10]}
        ''' 
        output_file = self.folder_name + output_file

        if dtw_tuner is None:
            dtw_tuner = {
                'constraint': ['default'],
                'slope': [],
                'radius': []
            }
        
        if knn_tuner is None:
            knn_tuner = [5]
        
        if date_tuner is None:
            date_tuner = {
                'start': [2020],
                'year_time': [5]
            }

        with open(output_file, 'w') as f:
            # Write header information
            f.write("=" * 80 + "\n")
            f.write(f"SAWAH CLASSIFICATION KNN-DTW TUNING EXPERIMENT\n")
            f.write(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write(f"Dataset: {self.filename}\n")
            f.write(f"Labels: {self.labeled_filename}\n")
            f.write(f"EVI mode: {self.evi}\n")
            f.write("=" * 80 + "\n\n")
            
            # Write experiment parameters
            f.write("EXPERIMENT PARAMETERS:\n")
            f.write(f"DTW constraints: {dtw_tuner['constraint']}\n")
            f.write(f"DTW slopes: {dtw_tuner['slope']}\n")
            f.write(f"DTW radii: {dtw_tuner['radius']}\n")
            f.write(f"KNN values: {knn_tuner}\n")
            f.write(f"Start years: {date_tuner['start']}\n")
            f.write(f"Year spans: {date_tuner['year_time']}\n\n")
            
        date_columns = [col for col in self.X_sawah.columns]

        # encode label menjadi numerik agar lebih hemat dalam memproses
        le = LabelEncoder()
        y_encoded = le.fit_transform(self.y_sawah)
        
        # hitung jumlah iterasi
        total_iterations = (len(dtw_tuner['constraint']) * len(dtw_tuner['slope']) * 
                            len(dtw_tuner['radius']) * len(knn_tuner) * 
                            len(date_tuner['start']) * len(date_tuner['year_time']))
        
        print(f"Total kombinasi yang diuji: {total_iterations}\n")
        
        with open(output_file, 'a') as f:
            f.write(f"Total combinations to test: {total_iterations}\n\n")
            f.write("RESULTS:\n")
            f.write("-" * 80 + "\n")
            f.write("{:<5} {:<15} {:<20} {:<15} {:<10} {:<15}\n".format(
                "Iter", "Year Range", "DTW Parameters", "k", "Accuracy", "Time (s)"))
            f.write("-" * 80 + "\n")
        
        print("Mulai hyperparameter tuning...")
        start_time = time.time()
        
        best_acc = 0
        best_params = {
            'dtw': None,
            'k': None,
            'year': None,
            'acc': 0
        }
        best_model = None

        iteration = 0
        for start_year in date_tuner['start']:
            for year_span in date_tuner['year_time']:
                # Filter date berdasarkan rentang date yang ingin diambil
                year_columns = [str(col) for col in date_columns 
                               if int(col[:4]) >= start_year and 
                               int(col[:4]) < start_year + year_span]

                # print(date_columns)
                # print(year_columns)
                # print(self.X_sawah.head()) 
                X_subset = self.X_sawah[year_columns]
                
                # Loop through DTW parameters
                for constraint in dtw_tuner['constraint']:
                    for slope in dtw_tuner['slope']:
                        for radius in dtw_tuner['radius']:
                            # Create DTW distance function with current parameters
                            dtw_params = {
                                'constraint': constraint,
                                'slope': slope,
                                'radius': radius
                            }
                            
                            distance_metric = self.get_metric_func(dtw_params)
                            
                            for k in knn_tuner:
                                iteration_start_time = time.time()
                                iteration += 1
                                print(f"Testing combination {iteration}/{total_iterations}: "
                                      f"years={start_year}-{start_year+year_span}, "
                                      f"DTW={dtw_params}, k={k}")
                                
                                knn = KNeighborsClassifier(
                                    n_neighbors=k,
                                    metric=distance_metric
                                )
                                
                                curr_acc = self.k_fold(knn, X=X_subset, y=y_encoded)

                                iteration_time = time.time() - iteration_start_time
                                dtw_str = f"{constraint}"
                                if slope is not None:
                                    dtw_str += f", slope={slope}"
                                if radius is not None:
                                    dtw_str += f", rad={radius}"
                                    
                                with open(output_file, 'a') as f:
                                    f.write("{:<5} {:<15} {:<20} {:<15} {:<10.4f} {:<15.2f}\n".format(
                                        iteration, 
                                        f"{start_year}-{start_year+year_span}", 
                                        dtw_str,
                                        k,
                                        curr_acc,
                                        iteration_time
                                    ))
                                os.system("clear")
                                print(f"Accuracy: {curr_acc:.4f}")
                                
                                if curr_acc > best_acc:
                                    best_acc = curr_acc
                                    best_params = {
                                        'dtw': dtw_params,
                                        'k': k,
                                        'year': {
                                            'start': start_year,
                                            'span': year_span
                                        },
                                        'acc': curr_acc
                                    }
                                    best_model = knn
                                    with open(output_file, 'a') as f:
                                        f.write(f">>> NEW BEST: Accuracy={best_acc:.4f} <<<\n")
                                    print(f"New best accuracy: {best_acc:.4f} with parameters: {best_params}")
        
        # Update best parameters
        self.best_params = best_params
        self.best_model = best_model

        total_time = time.time() - start_time
        
        with open(output_file, 'a') as f:
            f.write("-" * 80 + "\n\n")
            f.write("SUMMARY:\n")
            f.write(f"Total tuning time: {total_time:.2f} seconds\n")
            f.write(f"Best accuracy: {best_params['acc']:.4f}\n")
            f.write(f"Best parameters:\n")
            f.write(f"{best_params}")
        
        print(f"--- Tuning completed in {total_time:.2f} seconds ---")
        print(f"Best parameters: {best_params}")
    
    def k_fold(self, model, X=None, y=None, folds=10):
        skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=self.random_state)

        X_sawah = X if X is not None else self.X_sawah
        y_sawah = y if y is not None else self.y_sawah

        # print(X_sawah.shape)
        # print(y_sawah.shape)
        stratified_cv_scores = cross_val_score(model, X_sawah, y_sawah, cv=skf, scoring='accuracy')
        curr_acc = np.mean(stratified_cv_scores)
        return curr_acc
    
    def get_metric_func(self, dtw_params):
        constraint = dtw_params['constraint']
        slope = dtw_params['slope']
        radius = dtw_params['radius']
        
        def dtw_distance(x, y):
            x_formatted = to_time_series(x)
            y_formatted = to_time_series(y) 
            dtw_score = dtw(x_formatted, y_formatted)
            if(constraint == 'itakura'):
                dtw_score = dtw(x_formatted, y_formatted, global_constraint="itakura", itakura_max_slope=slope)
            elif(constraint == 'sakoe_chiba'):
                dtw_score = dtw(x_formatted, y_formatted, global_constraint="sakoe_chiba", sakoe_chiba_radius=radius)
            return dtw_score
        return dtw_distance

    def save_model(self):
        if self.best_model is not None:
            print("Optimized model not found, try to run tune() or load_model() first")
        else:
            print("Saving...")
            pickle.dump(self.best_model, open(self.folder_name + 'saved_models/' + f'classification_{curr_kec}.pkl', 'wb'))
            print(f"Model successfully saved in /saved_models")

    def load_model(self, model_filename):
        try:
            self.best_model = pickle.load(open(self.folder_name + 'saved_models/' + model_filename, 'rb'))
            print("Model loaded in best_model parameter")
        except:
            print("Model loading Error")

    def predict(self):
        start_year = self.best_params['year']['start']
        span = self.best_params['year']['start']

# %%
test_tuning = SawahClassification_KNNDTW(filename='campaka.csv', labeled_filename='label_sawah_nonsawah_campaka.csv')
# Out:
# Labeled data: (82, 733)
# Non-labeled data: (5273, 733)
# --- Preprocessing done in 0.8624639511108398 seconds ---

# %%
dtw_tuner = {'constraint': ['default', 'sakoe_chiba', 'itakura'], 'slope':[1, 2, 3], 'radius': [3, 5, 7]}
knn_tuner = [3, 5, 7, 9, 11]
date_tuner = {'start': [2018, 2020], 'year_time': [3, 5]}

test_tuning.tune(dtw_tuner=dtw_tuner, knn_tuner=knn_tuner, date_tuner=date_tuner, output_file='testingaja.txt')
# Out:
# Total kombinasi yang diuji: 540
#
# Mulai hyperparameter tuning...
# Testing combination 1/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 3}, k=3
# Accuracy: 0.7875
# New best accuracy: 0.7875 with parameters: {'dtw': {'constraint': 'default', 'slope': 1, 'radius': 3}, 'k': 3, 'year': {'start': 2018, 'span': 3}, 'acc': 0.7875}
# Testing combination 2/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 3}, k=5
# Accuracy: 0.8208
# New best accuracy: 0.8208 with parameters: {'dtw': {'constraint': 'default', 'slope': 1, 'radius': 3}, 'k': 5, 'year': {'start': 2018, 'span': 3}, 'acc': 0.8208333333333332}
# Testing combination 3/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 3}, k=7
# Accuracy: 0.8111
# Testing combination 4/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 3}, k=9
# Accuracy: 0.8347
# New best accuracy: 0.8347 with parameters: {'dtw': {'constraint': 'default', 'slope': 1, 'radius': 3}, 'k': 9, 'year': {'start': 2018, 'span': 3}, 'acc': 0.8347222222222221}
# Testing combination 5/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 3}, k=11
# Accuracy: 0.8125
# Testing combination 6/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 5}, k=3
# Accuracy: 0.7875
# Testing combination 7/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 5}, k=5
# Accuracy: 0.8208
# Testing combination 8/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 5}, k=7
# Accuracy: 0.8111
# Testing combination 9/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 5}, k=9
# Accuracy: 0.8347
# Testing combination 10/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 5}, k=11
# Accuracy: 0.8125
# Testing combination 11/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=3
# Accuracy: 0.7875
# Testing combination 12/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=5
# Accuracy: 0.8208
# Testing combination 13/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=7
# Accuracy: 0.8111
# Testing combination 14/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=9
# Accuracy: 0.8347
# Testing combination 15/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=11
# Accuracy: 0.8125
# Testing combination 16/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=3
# Accuracy: 0.7875
# Testing combination 17/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=5
# Accuracy: 0.8208
# Testing combination 18/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=7
# Accuracy: 0.8111
# Testing combination 19/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=9
# Accuracy: 0.8347
# Testing combination 20/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=11
# Accuracy: 0.8125
# Testing combination 21/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=3
# Accuracy: 0.7875
# Testing combination 22/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=5
# Accuracy: 0.8208
# Testing combination 23/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=7
# Accuracy: 0.8111
# Testing combination 24/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=9
# Accuracy: 0.8347
# Testing combination 25/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=11
# Accuracy: 0.8125
# Testing combination 26/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=3
# Accuracy: 0.7875
# Testing combination 27/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=5
# Accuracy: 0.8208
# Testing combination 28/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=7
# Accuracy: 0.8111
# Testing combination 29/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=9
# Accuracy: 0.8347
# Testing combination 30/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=11
# Accuracy: 0.8125
# Testing combination 31/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=3
# Accuracy: 0.7875
# Testing combination 32/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=5
# Accuracy: 0.8208
# Testing combination 33/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=7
# Accuracy: 0.8111
# Testing combination 34/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=9
# Accuracy: 0.8347
# Testing combination 35/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=11
# Accuracy: 0.8125
# Testing combination 36/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=3
# Accuracy: 0.7875
# Testing combination 37/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=5
# Accuracy: 0.8208
# Testing combination 38/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=7
# Accuracy: 0.8111
# Testing combination 39/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=9
# Accuracy: 0.8347
# Testing combination 40/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=11
# Accuracy: 0.8125
# Testing combination 41/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=3
# Accuracy: 0.7875
# Testing combination 42/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=5
# Accuracy: 0.8208
# Testing combination 43/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=7
# Accuracy: 0.8111
# Testing combination 44/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=9
# Accuracy: 0.8347
# Testing combination 45/540: years=2018-2021, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=11
# Accuracy: 0.8125
# Testing combination 46/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=3
# Accuracy: 0.8111
# Testing combination 47/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=5
# Accuracy: 0.8361
# New best accuracy: 0.8361 with parameters: {'dtw': {'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, 'k': 5, 'year': {'start': 2018, 'span': 3}, 'acc': 0.836111111111111}
# Testing combination 48/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=7
# Accuracy: 0.8097
# Testing combination 49/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=9
# Accuracy: 0.8236
# Testing combination 50/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=11
# Accuracy: 0.8333
# Testing combination 51/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=3
# Accuracy: 0.8347
# Testing combination 52/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=5
# Accuracy: 0.8472
# New best accuracy: 0.8472 with parameters: {'dtw': {'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, 'k': 5, 'year': {'start': 2018, 'span': 3}, 'acc': 0.8472222222222221}
# Testing combination 53/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=7
# Accuracy: 0.8458
# Testing combination 54/540: years=2018-2021, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=9
# Accuracy: 0
540: years=2020-2025, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=7
# Accuracy: 0.8250
# Testing combination 419/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=9
# Accuracy: 0.8583
# Testing combination 420/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 1, 'radius': 7}, k=11
# Accuracy: 0.8139
# Testing combination 421/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=3
# Accuracy: 0.8458
# Testing combination 422/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=5
# Accuracy: 0.8569
# Testing combination 423/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=7
# Accuracy: 0.8250
# Testing combination 424/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=9
# Accuracy: 0.8583
# Testing combination 425/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 3}, k=11
# Accuracy: 0.8139
# Testing combination 426/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=3
# Accuracy: 0.8458
# Testing combination 427/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=5
# Accuracy: 0.8569
# Testing combination 428/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=7
# Accuracy: 0.8250
# Testing combination 429/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=9
# Accuracy: 0.8583
# Testing combination 430/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 5}, k=11
# Accuracy: 0.8139
# Testing combination 431/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=3
# Accuracy: 0.8458
# Testing combination 432/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=5
# Accuracy: 0.8569
# Testing combination 433/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=7
# Accuracy: 0.8250
# Testing combination 434/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=9
# Accuracy: 0.8583
# Testing combination 435/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 2, 'radius': 7}, k=11
# Accuracy: 0.8139
# Testing combination 436/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=3
# Accuracy: 0.8458
# Testing combination 437/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=5
# Accuracy: 0.8569
# Testing combination 438/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=7
# Accuracy: 0.8250
# Testing combination 439/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=9
# Accuracy: 0.8583
# Testing combination 440/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 3}, k=11
# Accuracy: 0.8139
# Testing combination 441/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=3
# Accuracy: 0.8458
# Testing combination 442/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=5
# Accuracy: 0.8569
# Testing combination 443/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=7
# Accuracy: 0.8250
# Testing combination 444/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=9
# Accuracy: 0.8583
# Testing combination 445/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 5}, k=11
# Accuracy: 0.8139
# Testing combination 446/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=3
# Accuracy: 0.8458
# Testing combination 447/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=5
# Accuracy: 0.8569
# Testing combination 448/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=7
# Accuracy: 0.8250
# Testing combination 449/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=9
# Accuracy: 0.8583
# Testing combination 450/540: years=2020-2025, DTW={'constraint': 'default', 'slope': 3, 'radius': 7}, k=11
# Accuracy: 0.8139
# Testing combination 451/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=3
# Accuracy: 0.8208
# Testing combination 452/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=5
# Accuracy: 0.7986
# Testing combination 453/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=7
# Accuracy: 0.8125
# Testing combination 454/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=9
# Accuracy: 0.8111
# Testing combination 455/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 3}, k=11
# Accuracy: 0.8236
# Testing combination 456/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=3
# Accuracy: 0.8347
# Testing combination 457/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=5
# Accuracy: 0.7861
# Testing combination 458/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=7
# Accuracy: 0.8236
# Testing combination 459/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=9
# Accuracy: 0.8000
# Testing combination 460/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 5}, k=11
# Accuracy: 0.8236
# Testing combination 461/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 7}, k=3
# Accuracy: 0.8458
# Testing combination 462/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 7}, k=5
# Accuracy: 0.8097
# Testing combination 463/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 7}, k=7
# Accuracy: 0.8222
# Testing combination 464/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 7}, k=9
# Accuracy: 0.8111
# Testing combination 465/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 7}, k=11
# Accuracy: 0.8472
# Testing combination 466/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 3}, k=3
# Accuracy: 0.8208
# Testing combination 467/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 3}, k=5
# Accuracy: 0.7986
# Testing combination 468/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 3}, k=7
# Accuracy: 0.8125
# Testing combination 469/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 3}, k=9
# Accuracy: 0.8111
# Testing combination 470/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 3}, k=11
# Accuracy: 0.8236
# Testing combination 471/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 5}, k=3
# Accuracy: 0.8347
# Testing combination 472/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 5}, k=5
# Accuracy: 0.7861
# Testing combination 473/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 5}, k=7
# Accuracy: 0.8236
# Testing combination 474/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 5}, k=9
# Accuracy: 0.8000
# Testing combination 475/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 5}, k=11
# Accuracy: 0.8236
# Testing combination 476/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 7}, k=3
# Accuracy: 0.8458
# Testing combination 477/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 7}, k=5
# Accuracy: 0.8097
# Testing combination 478/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 7}, k=7
# Accuracy: 0.8222
# Testing combination 479/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 7}, k=9
# Accuracy: 0.8111
# Testing combination 480/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 2, 'radius': 7}, k=11
# Accuracy: 0.8472
# Testing combination 481/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 3}, k=3
# Accuracy: 0.8208
# Testing combination 482/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 3}, k=5
# Accuracy: 0.7986
# Testing combination 483/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 3}, k=7
# Accuracy: 0.8125
# Testing combination 484/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 3}, k=9
# Accuracy: 0.8111
# Testing combination 485/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 3}, k=11
# Accuracy: 0.8236
# Testing combination 486/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 5}, k=3
# Accuracy: 0.8347
# Testing combination 487/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 5}, k=5
# Accuracy: 0.7861
# Testing combination 488/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 5}, k=7
# Accuracy: 0.8236
# Testing combination 489/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 5}, k=9
# Accuracy: 0.8000
# Testing combination 490/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 5}, k=11
# Accuracy: 0.8236
# Testing combination 491/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 7}, k=3
# Accuracy: 0.8458
# Testing combination 492/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 7}, k=5
# Accuracy: 0.8097
# Testing combination 493/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 7}, k=7
# Accuracy: 0.8222
# Testing combination 494/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 7}, k=9
# Accuracy: 0.8111
# Testing combination 495/540: years=2020-2025, DTW={'constraint': 'sakoe_chiba', 'slope': 3, 'radius': 7}, k=11
# Accuracy: 0.8472
# Testing combination 496/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 3}, k=3
# Accuracy: 0.8000
# Testing combination 497/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 3}, k=5
# Accuracy: 0.7639
# Testing combination 498/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 3}, k=7
# Accuracy: 0.7750
# Testing combination 499/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 3}, k=9
# Accuracy: 0.7764
# Testing combination 500/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 3}, k=11
# Accuracy: 0.7986
# Testing combination 501/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 5}, k=3
# Accuracy: 0.8000
# Testing combination 502/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 5}, k=5
# Accuracy: 0.7639
# Testing combination 503/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 5}, k=7
# Accuracy: 0.7750
# Testing combination 504/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 5}, k=9
# Accuracy: 0.7764
# Testing combination 505/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 5}, k=11
# Accuracy: 0.7986
# Testing combination 506/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 7}, k=3
# Accuracy: 0.8000
# Testing combination 507/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 7}, k=5
# Accuracy: 0.7639
# Testing combination 508/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 7}, k=7
# Accuracy: 0.7750
# Testing combination 509/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 7}, k=9
# Accuracy: 0.7764
# Testing combination 510/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 1, 'radius': 7}, k=11
# Accuracy: 0.7986
# Testing combination 511/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 3}, k=3
# Accuracy: 0.8569
# Testing combination 512/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 3}, k=5
# Accuracy: 0.8458
# Testing combination 513/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 3}, k=7
# Accuracy: 0.8125
# Testing combination 514/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 3}, k=9
# Accuracy: 0.8125
# Testing combination 515/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 3}, k=11
# Accuracy: 0.8250
# Testing combination 516/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 5}, k=3
# Accuracy: 0.8569
# Testing combination 517/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 5}, k=5
# Accuracy: 0.8458
# Testing combination 518/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 5}, k=7
# Accuracy: 0.8125
# Testing combination 519/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 5}, k=9
# Accuracy: 0.8125
# Testing combination 520/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 5}, k=11
# Accuracy: 0.8250
# Testing combination 521/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 7}, k=3
# Accuracy: 0.8569
# Testing combination 522/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 7}, k=5
# Accuracy: 0.8458
# Testing combination 523/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 7}, k=7
# Accuracy: 0.8125
# Testing combination 524/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 7}, k=9
# Accuracy: 0.8125
# Testing combination 525/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 2, 'radius': 7}, k=11
# Accuracy: 0.8250
# Testing combination 526/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 3}, k=3
# Accuracy: 0.8569
# Testing combination 527/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 3}, k=5
# Accuracy: 0.8347
# Testing combination 528/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 3}, k=7
# Accuracy: 0.8125
# Testing combination 529/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 3}, k=9
# Accuracy: 0.8125
# Testing combination 530/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 3}, k=11
# Accuracy: 0.8139
# Testing combination 531/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 5}, k=3
# Accuracy: 0.8569
# Testing combination 532/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 5}, k=5
# Accuracy: 0.8347
# Testing combination 533/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 5}, k=7
# Accuracy: 0.8125
# Testing combination 534/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 5}, k=9
# Accuracy: 0.8125
# Testing combination 535/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 5}, k=11
# Accuracy: 0.8139
# Testing combination 536/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 7}, k=3
# Accuracy: 0.8569
# Testing combination 537/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 7}, k=5
# Accuracy: 0.8347
# Testing combination 538/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 7}, k=7
# Accuracy: 0.8125
# Testing combination 539/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 7}, k=9
# Accuracy: 0.8125
# Testing combination 540/540: years=2020-2025, DTW={'constraint': 'itakura', 'slope': 3, 'radius': 7}, k=11
# Accuracy: 0.8139
# --- Tuning completed in 6097.87 seconds ---
# Best parameters: {'dtw': {'constraint': 'sakoe_chiba', 'slope': 1, 'radius': 7}, 'k': 11, 'year': {'start': 2018, 'span': 3}, 'acc': 0.8583333333333332}

# %%
test_tuning.save_model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 test_tuning.save_model()
#
# Cell In[71], line 270, in SawahClassification_KNNDTW.save_model(self)
#     269 def save_model(self):
# --> 270     if not best_model:
#     271         print("Optimized model not found, try to run tune() or load_model() first")
#     272     else:
#
# NameError: name 'best_model' is not defined

# %%
folder_name = 'sawah_classification/'

collected_data = ["campaka"]
evi = True
curr_kec = collected_data[0]
curr_kec = "evi_" + curr_kec if evi else curr_kec

#dtw_knn_2 -> datasetnya lebih besar
# https://code.earthengine.google.com/52607160b523092795f576172fb238b3

labeled_df = pd.read_csv(folder_name + "label_sawah_nonsawah_campaka.csv").drop([".geo", "system:index"], axis=1)
wilayah_df = pd.read_csv(folder_name + curr_kec + ".csv")
cluster_geo = wilayah_df[['cluster_id', '.geo']]
wilayah_df = wilayah_df.drop(".geo", axis=1)

# %%
wilayah_df.head()
# Out:
#                         system:index  \
# 0  2_LE07_122065_20130105_+2457+7221
# 1  2_LE07_122065_20130105_+2458+7220
# 2  2_LE07_122065_20130105_+2460+7230
# 3  2_LE07_122065_20130105_+2463+7225
# 4  2_LE07_122065_20130105_+2466+7193
#
#    1_1_1_20181216T030121_20181216T031247_T48MYT  \
# 0                                      0.504244
# 1                                      0.376401
# 2                                      0.507479
# 3                                      0.493706
# 4                                      0.520024
#
#    1_1_1_20181221T030129_20181221T031355_T48MYT  \
# 0                                      0.504244
# 1                                      0.339200
# 2                                      0.507479
# 3                                      0.493706
# 4                                      0.474593
#
#    1_1_1_20181226T030121_20181226T031527_T48MYT  \
# 0                                      0.504244
# 1                                      0.376401
# 2                                      0.507479
# 3                                      0.493706
# 4                                      0.520024
#
#    1_1_1_20181231T030129_20181231T031947_T48MYT  \
# 0                                      0.479911
# 1                                      0.245314
# 2                                      0.337438
# 3                                      0.465628
# 4                                      0.270665
#
#    1_1_1_20190105T030111_20190105T030703_T48MYT  \
# 0                                      0.479911
# 1                                      0.245314
# 2                                      0.337438
# 3                                      0.465628
# 4                                      0.270665
#
#    1_1_1_20190110T030109_20190110T031638_T48MYT  \
# 0                                      0.479911
# 1                                      0.245314
# 2                                      0.329510
# 3                                      0.393348
# 4                                      0.270665
#
#    1_1_1_20190115T030051_20190115T031146_T48MYT  \
# 0                                      0.479911
# 1                                      0.245314
# 2                                      0.329510
# 3                                      0.393348
# 4                                      0.270665
#
#    1_1_1_20190204T025921_20190204T030510_T48MYT  \
# 0                                      0.437620
# 1                                      0.404196
# 2                                      0.380260
# 3                                      0.418841
# 4                                      0.317043
#
#    1_1_1_20190209T025859_20190209T031204_T48MYT  ...  2_LE07_122065_20230825  \
# 0                                      0.437620  ...                0.460917
# 1                                      0.404196  ...                0.297690
# 2                                      0.380260  ...                0.330469
# 3                                      0.418841  ...                0.274154
# 4                                      0.317043  ...                0.395915
#
#    2_LE07_122065_20230921  2_LE07_122065_20231013  2_LE07_122065_20231114  \
# 0                0.425160                0.262072                0.293895
# 1                0.365815                0.236502                0.408677
# 2                0.487259                0.453060                0.293495
# 3                0.360330                0.318713                0.352528
# 4                0.364973                0.290607                0.325278
#
#    2_LE07_122065_20231119  2_LE07_122065_20231216  2_LE07_122065_20231221  \
# 0                0.293895                0.498646                0.498646
# 1                0.241304                0.276683                0.291183
# 2                0.219730                0.354005                0.385018
# 3                0.260867                0.383293                0.393935
# 4                0.325278                0.457557                0.445428
#
#    2_LE07_122065_20240117  2_LE07_123065_20221219  cluster_id
# 0                0.228976                0.456635  1089104212
# 1                0.211581                0.414024  1179512119
# 2                0.605126                0.355668  2092296463
# 3                0.230308                0.397656   762622032
# 4                0.223117                0.411338  2016193127
#
# [5 rows x 775 columns]

# %%
columns = wilayah_df.columns.tolist()
renamed_columns = []

for col in columns:
    colname = ""
    if "T48MYT" in col:
        colname = col.split("_")[3][:8]
    elif "LC08" in col:
        colname = col.split("_")[5]
    elif "LE07" in col:
        colname = col.split("_")[3]
    renamed_columns.append(colname)

renamed_columns = renamed_columns[:-1]

old_new_col = dict(zip(columns, renamed_columns))
wilayah_df = wilayah_df.rename(columns=old_new_col)

# %%
wilayah_df = wilayah_df.rename(columns=old_new_col)
# menghapus kolom yg namanya duplikat
wilayah_df = wilayah_df.loc[:, ~wilayah_df.columns.duplicated(keep='first')]

# mengurutkan kolom berdasarkan urutan tanggalnya
wilayah_df = wilayah_df.reindex(sorted(wilayah_df.columns), axis=1)

cluster_id = wilayah_df['cluster_id']
# print(cluster_id)
wilayah_df = wilayah_df.iloc[:, 1:-1].interpolate(axis=1)
wilayah_df = wilayah_df.bfill(axis=1)
wilayah_df = pd.concat([wilayah_df, cluster_id], axis=1)
print(wilayah_df)
# Out:
#       20130326  20130411  20130521  20130529  20130614  20130622  20130708  \
# 0     0.327694  0.305582  0.356301  0.356301  0.292157  0.292157  0.280064
# 1     0.400953  0.452391  0.414311  0.414311  0.390476  0.390476  0.323887
# 2     0.295016  0.295016  0.333011  0.333011  0.338050  0.338050  0.292006
# 3     0.435353  0.435353  0.326386  0.326386  0.332718  0.332718  0.272102
# 4     0.459074  0.522686  0.476411  0.476411  0.587645  0.587645  0.527148
# ...        ...       ...       ...       ...       ...       ...       ...
# 5350  0.360454  0.360454  0.360454  0.360454  0.360454  0.360454  0.360454
# 5351  0.461722  0.461722  0.461722  0.461722  0.461722  0.461722  0.461722
# 5352  0.506558  0.506558  0.506558  0.506558  0.506558  0.506558  0.506558
# 5353  0.412735  0.412735  0.412735  0.412735  0.412735  0.412735  0.412735
# 5354  0.413249  0.413249  0.413249  0.413249  0.413249  0.413249  0.413249
#
#       20130716  20130724  20130801  ...  20241010  20241015  20241020  \
# 0     0.353306  0.350829  0.403998  ...  0.481420  0.481420  0.407604
# 1     0.366830  0.358122  0.420763  ...  0.360462  0.406482  0.341404
# 2     0.358494  0.343404  0.403815  ...  0.479119  0.479119  0.321937
# 3     0.329649  0.325602  0.378386  ...  0.435331  0.463626  0.443099
# 4     0.530916  0.453008  0.491831  ...  0.330831  0.351788  0.316588
# ...        ...       ...       ...  ...       ...       ...       ...
# 5350  0.341668  0.322882  0.345902  ...  0.276969  0.369385  0.284136
# 5351  0.417390  0.373058  0.387776  ...  0.498536  0.498536  0.443371
# 5352  0.504034  0.501510  0.497764  ...  0.280340  0.323430  0.301237
# 5353  0.352732  0.292730  0.337379  ...  0.196619  0.407997  0.407997
# 5354  0.376986  0.340723  0.375344  ...  0.279603  0.305739  0.293611
#
#       20241025  20241026  20241030  20241104  20241109  20241111  cluster_id
# 0     0.407604  0.407604  0.407604  0.372187  0.372187  0.372187  1089104212
# 1     0.387362  0.339221  0.385263  0.324319  0.330125  0.324319  1179512119
# 2     0.321937  0.321937  0.321937  0.285192  0.285192  0.285192  2092296463
# 3     0.465973  0.443099  0.465973  0.428138  0.428138  0.428138   762622032
# 4     0.316588  0.316588  0.178339  0.234247  0.234247  0.234247  2016193127
# ...        ...       ...       ...       ...       ...       ...         ...
# 5350  0.259384  0.287650  0.287650  0.259384  0.259384  0.259384   529368290
# 5351  0.485026  0.485026  0.485026  0.485026  0.485026  0.485026  -628578455
# 5352  0.307318  0.315170  0.349478  0.342411  0.464495  0.464495  -689105372
# 5353  0.450940  0.450940  0.450940  0.450940  0.450940  0.450940  1459620303
# 5354  0.203212  0.293611  0.295964  0.229755  0.219839  0.219839  1592763732
#
# [5355 rows x 733 columns]

# %%
wilayah_labeled = wilayah_df[wilayah_df['cluster_id'].isin(labeled_df['cluster_id'])]
wilayah_not_labeled = wilayah_df[~wilayah_df['cluster_id'].isin(labeled_df['cluster_id'])]
print("labeled data: " + str(wilayah_labeled.shape))
print("non-labeled data: " + str(wilayah_not_labeled.shape))
# Out:
# labeled data: (82, 733)
# non-labeled data: (5273, 733)

# %%
labeled_merge = pd.merge(wilayah_labeled, labeled_df, on='cluster_id', how='left')
print(labeled_merge.head())

X_wk = labeled_merge.iloc[:, :-2]
y_wk = labeled_merge['label']
print(X_wk.shape)
X_train, X_test, y_train, y_test = train_test_split(X_wk, y_wk, test_size=0.25, random_state=42, stratify=y_wk)
print(X_train.shape)
# Out:
#    20130326  20130411  20130521  20130529  20130614  20130622  20130708  \
# 0  0.477506  0.454370  0.465716  0.465716  0.406312  0.445689  0.444031
# 1  0.534865  0.495621  0.517338  0.517338  0.594239  0.478058  0.509016
# 2  0.570269  0.585273  0.436227  0.436227  0.297267  0.290693  0.287736
# 3  0.522224  0.447661  0.373097  0.373097  0.348911  0.374415  0.388258
# 4  0.513228  0.513228  0.513228  0.513228  0.382734  0.399115  0.420852
#
#    20130716  20130724  20130801  ...  20241015  20241020  20241025  20241026  \
# 0  0.432696  0.436712  0.487838  ...  0.533244  0.527191  0.517106  0.458576
# 1  0.500448  0.514464  0.571021  ...  0.417373  0.419279  0.391296  0.407959
# 2  0.309770  0.316253  0.433990  ...  0.551536  0.451460  0.432323  0.419969
# 3  0.389659  0.403633  0.465197  ...  0.571121  0.560780  0.555044  0.515061
# 4  0.417423  0.411189  0.434912  ...  0.485001  0.472558  0.445774  0.428328
#
#    20241030  20241104  20241109  20241111  cluster_id      label
# 0  0.574276  0.583299  0.583930  0.580531 -1815857134  non-sawah
# 1  0.440419  0.437447  0.471128  0.471128   402047594  non-sawah
# 2  0.451460  0.451460  0.451460  0.451460  -917794643      sawah
# 3  0.564711  0.564221  0.578592  0.578592  -637045209      sawah
# 4  0.472558  0.472558  0.472558  0.472558  -238404423  non-sawah
#
# [5 rows x 734 columns]
# (85, 732)
# (63, 732)

# %%
constraint = "sakoe_chiba" # '' atau 'itakura' 'sakoe_chiba'
slope = 2
radius = 5

def dtw_distance(x, y):
    x_formatted = to_time_series(x)
    y_formatted = to_time_series(y) 
    dtw_score = dtw(x_formatted, y_formatted)
    if(constraint == 'itakura'):
        dtw_score = dtw(x_formatted, y_formatted, global_constraint="itakura", itakura_max_slope=slope)
    elif(constraint == 'sakoe_chiba'):
        dtw_score = dtw(x_formatted, y_formatted, global_constraint="sakoe_chiba", sakoe_chiba_radius=radius)
    return dtw_score

knn_1 = KNeighborsClassifier(n_neighbors = 5, metric=dtw_distance)
knn_1.fit(X_train, y_train)

y_pred = knn_1.predict(X_test)

# %%
def evaluate(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=np.unique(y_test), 
                yticklabels=np.unique(y_test))
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
evaluate(y_test, y_pred)
# Out:
# Accuracy: 0.6364
# Precision: 0.6941
# Recall: 0.6364
# F1 Score: 0.6071

# %%
scoring = {
    'accuracy': 'accuracy',
    'precision': make_scorer(precision_score, average='weighted'),
    'recall': make_scorer(recall_score, average='weighted'),
    'f1': make_scorer(f1_score, average='weighted')
}


# print(scoring)
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

stratified_cv_scores = cross_val_score(knn_1, X_wk, y_wk, cv=skf, scoring='accuracy')

print("\nStratified k-fold results:")
for i, score in enumerate(stratified_cv_scores):
    print(f"Fold {i+1}: {score:.4f}")

print(f"\nAverage accuracy (stratified): {np.mean(stratified_cv_scores):.4f}")
print(f"Standard deviation (stratified): {np.std(stratified_cv_scores):.4f}")
#with larger dataset

start_time = time.time()
final_model = KNeighborsClassifier(n_neighbors=5, metric=dtw_score)
final_model.fit(X_wk, y_wk)

pickle.dump(final_model, open(folder_name + 'saved_models/' + f'classification_{curr_kec}.pkl', 'wb'))
predict_all = final_model.predict(wilayah_not_labeled.iloc[:, :-1])
unlabeled_df = wilayah_not_labeled.copy()
unlabeled_df['label'] = predict_all
predicted_df = unlabeled_df.copy()

model_df = wilayah_labeled.copy()
final_df = pd.concat([model_df, predicted_df], axis=0)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Stratified k-fold results:
# Fold 1: 0.7778
# Fold 2: 1.0000
# Fold 3: 0.8889
# Fold 4: 1.0000
# Fold 5: 0.5556
# Fold 6: 0.8750
# Fold 7: 0.6250
# Fold 8: 0.7500
# Fold 9: 0.7500
# Fold 10: 0.8750
#
# Average accuracy (stratified): 0.8097
# Standard deviation (stratified): 0.1393

# %%
sawah_clusters = final_df[final_df['label'] == 'sawah']
cluster_ids = sawah_clusters['cluster_id'].tolist()

# %%
print(cluster_ids)
# Out:
# [-917794643.0, 311245178.0, -1650217684.0, 2124792546.0, -688633003.0, 1227641531.0, 1388155823.0, -1270827916.0, 1052306339.0, 915438257.0, -1132344047.0, 214820671.0, 343287607.0, -1344971223.0, 1789762246.0, -1449462029.0, -452163700.0, -1029889705.0, -1627081551.0, 599283644.0, 587744584.0, -263205183.0, -193013299.0, 197816647.0, 135003530.0, -2142798840.0, 2098126633.0, -1340001761.0, -1874608788.0, -1741580654.0, -371864521.0, 455897423.0, 35335500.0, 98334114.0, 344793503.0, 172473050.0, 131791723.0, 185122031.0, -1727544214.0, -523515288.0, 377971710.0, 1951536363.0, -1362720936.0, 921279356.0, -65749960.0, 142836573.0, -836217663.0, 2074493430.0, -904121058.0, 79397419.0, 951742797.0, 2092296463.0, -2106052113.0, 1233805816.0, -693147847.0, 355636100.0, 1805711005.0, -814502746.0, 362115070.0, 421884622.0, -178900516.0, 1417642363.0, 1611174765.0, -921939249.0, -2001110783.0, 857631799.0, 437925902.0, 1231212897.0, -608069479.0, -824688566.0, -653032671.0, -172145166.0, 1198596328.0, -989098673.0, 629807881.0, -810694167.0, -328444620.0, -1251324908.0, 83888759.0, -1158057075.0, 2084808330.0, -970220404.0, 2117519437.0, -1968520626.0, -1569660879.0, 42617593.0, -1867