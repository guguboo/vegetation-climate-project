# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests

import warnings
warnings.filterwarnings('ignore')

# %%
era5_features = [
        # Temperature variables
        'temperature_2m',                       # Air temperature
        'temperature_2m_min',                   # Daily minimum air temperature
        'temperature_2m_max',                   # Daily maximum air temperature
        'soil_temperature_level_1',             # Topsoil temperature (0-7 cm)
        'soil_temperature_level_2',             # Soil temperature (7-28 cm)
        
        # Moisture variables
        'volumetric_soil_water_layer_1',        # Topsoil moisture content
        'volumetric_soil_water_layer_2',        # Soil moisture (7-28 cm)
        'volumetric_soil_water_layer_3',        # Soil moisture (28-100 cm)
        'total_precipitation_sum',              # Total rainfall and snow
        'dewpoint_temperature_2m',              # Air humidity indicator
        
        # Radiation and energy variables
        'surface_solar_radiation_downwards_sum', # Solar radiation at surface
        'surface_net_solar_radiation_sum',       # Net solar radiation at surface
        
        # Evaporation and water cycle
        'total_evaporation_sum',                 # Actual evaporation
        
        # Wind variables
        'u_component_of_wind_10m',               # East-west wind component
        'v_component_of_wind_10m'                # North-south wind component
    ]

openweather_features = [
        'temp',         # Current temperature (C or K depending on units)
        'feels_like',   # Perceived temperature considering humidity and wind (C or K)
        'temp_min',     # Minimum temperature at the moment (C or K)
        'temp_max',     # Maximum temperature at the moment (C or K)
        'pressure',     # Atmospheric pressure at sea level (hPa)
        'humidity',     # Humidity percentage (%)
        'wind_speed',   # Wind speed (meter/sec)
        'wind_deg',     # Wind direction in degrees (0–360)
        'rain_1h',      # Rain volume for the last 1 hour (mm)
        'rain_3h',      # Rain volume for the last 3 hours (mm)
        'clouds_all'    # Cloudiness percentage (%)
    ]

chirts_features = [
        'heat_index',
        'maximum_temperature',
        'minimum_temperature',
        'relative_humidity',
        'saturation_vapor_pressure',
        'vapor_pressure_deficit',
    ]

power_features = [
        'T2M',           # MERRA-2 Temperature at 2 Meters (C)
        'T2MDEW',        # MERRA-2 Dew/Frost Point at 2 Meters (C)
        'T2MWET',        # MERRA-2 Wet Bulb Temperature at 2 Meters (C)
        'TS',            # MERRA-2 Earth Skin Temperature (C)
        'T2M_RANGE',     # MERRA-2 Temperature at 2 Meters Range (C)
        'T2M_MAX',       # MERRA-2 Temperature at 2 Meters Maximum (C)
        'T2M_MIN',       # MERRA-2 Temperature at 2 Meters Minimum (C)
        'PS',            # MERRA-2 Surface Pressure (kPa)
        'WS2M',          # MERRA-2 Wind Speed at 2 Meters (m/s)
        'WS2M_MAX',      # MERRA-2 Wind Speed at 2 Meters Maximum (m/s)
        'WS2M_MIN',      # MERRA-2 Wind Speed at 2 Meters Minimum (m/s)
        'GWETTOP',       # MERRA-2 Surface Soil Wetness (1)
        'GWETROOT'      # MERRA-2 Root Zone Soil Wetness (1)
    ]

selected_features = era5_features

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# konfigurasi parameter
start_year = 2020
end_year = 2025
climate_dir = "climate_timeseries/cleaned/"
vegetation_dir = "pandanwangi_timeseries/"
viz_dir = "visualization/"
evi = True
kecamatan_names = ['warungkondang']

era5_datasets = ['era5_warungkondang.csv']
chirts_datasets = ['chirts_warungkondang.csv']
ow_datasets = ['OpenWeather_warungkondang.csv']
power_datasets = ['power_warungkondang.csv']

selected_dataset = era5_datasets

available_vegetation_datasets = ['warungkondang.csv']

selected_kec = kecamatan_names[0]

if evi:
    available_vegetation_datasets = ['evi_' + dataset for dataset in available_vegetation_datasets]

extract_statistics = ['mean', 'min', 'max', 'std']
statistic_corr = ['mean', 'min', 'max', 'std', 'smoothed_mean']

temporal_resolution = '5D'

# %%
# load seluruh data climate
def load_climate_data(climate_dir, datasets, kecamatan_names):
    climate_df = {}
    for i, dataset in enumerate(selected_dataset):
        try:
            curr = pd.read_csv(f"{climate_dir}/{dataset}")
            kec = kecamatan_names[min(i, len(kecamatan_names)-1)]
            climate_df[kec] = curr
        except Exception as e:
            print(f"File kecamatan {kec} tidak dapat dimuat: {e}")
    return climate_df

# load seluruh data vegetasi
def load_vegetation_data(vegetation_dir, datasets, kecamatan_names):
    vegetation_df = {}
    for i, dataset in enumerate(datasets):
        try:
            curr = pd.read_csv(f"{vegetation_dir}/{dataset}")
            kec = kecamatan_names[min(i, len(kecamatan_names)-1)]
            vegetation_df[kec] = curr
        except Exception as e:
            print(f"File vegetasi {kec} tidak dapat dimuat: {e}")
    return vegetation_df

# process data cuaca
def climate_df_processing(df):
    df['datetime'] = pd.to_datetime(df['datetime'], format='%Y-%m-%d')
    df.set_index('datetime', inplace=True)
    
    return df[(df.index.year >= start_year) & (df.index.year <= end_year)]

# process data vegetasi
def vegetation_preprocessing(df):
    df = df.iloc[:,1:]
    df = df[df.label == 'pandanwangi']
    df = df.set_index('cluster_id') 
    df = df.describe()
    df = df.T # transpose urutan waktu menjadi baris
    df = df[extract_statistics] # ambil fitur statistik yang diinginkan dari .describe()
    
    indexes = df.index
    new_indexes = []
    for i in indexes:
        date = pd.to_datetime(i, format='%Y%m%d')
        new_indexes.append(date)
    
    df['datetime'] = new_indexes
    df = df.set_index('datetime')
    df = df.asfreq(temporal_resolution, method='nearest') # resample data, dengan space temporal menjadi per 5 hari dengan metode nilai terdekat
    
    return df[(df.index.year >= start_year) & (df.index.year <= end_year)]

# function untuk mem-filter dataframe dengan metode savitzky-golay 
def smoothing_sg(df, window_length=16, polyorder=3):
    for col in ['mean', 'min', 'max']:
        filtered = savgol_filter(df[col], window_length=window_length, polyorder=polyorder)
        df[f'smoothed_{col}'] = filtered
    return df


# melakukan differencing pada data time series
def difference_df(df):
    return df.diff()
    
# mengecek stasioneritas pada data dengan Dicky-Fuller test dengan alpha 5%
def test_stationarity(df):
    results = {}
    for col in df.columns:
        adf_result = sm.tsa.stattools.adfuller(df[col].dropna())
        results[col] = {
            'ADF Statistic': adf_result[0],
            'p-value': adf_result[1],
            'Stationary': adf_result[1] < 0.05
        }
    return pd.DataFrame(results).T

# hitung korelasi dengan lag
def calculate_lagged_correlation(climate_df, vegetation_df, max_lag=30):
    vegetation_stats = statistic_corr
    
    lag_correlation = {
        'statistic': [],
        'climate_feature': [],
        'lag': [],
        'correlation': [],
        'p_value': []
    }
    
    for stat in vegetation_stats:
        if stat in vegetation_df.columns:
            veg_series = vegetation_df[stat]
            
            for feature in climate_df.columns:
                climate_series = climate_df[feature]
                
                intersecting_idx = veg_series.index.intersection(climate_series.index) # kedua dataset yang dibandingkan mempunyai index yang sama (time range yang sama)
                veg_adjusted = veg_series.loc[intersecting_idx]
                climate_adjusted = climate_series.loc[intersecting_idx]
                
                # hitung cross-correlation untuk lag 0 hingga 30 (pada time series)
                for lag in range(max_lag+1):
                    x = climate_adjusted.iloc[:-lag].values if lag != 0 else climate_adjusted.values
                    y = veg_adjusted.iloc[lag:].values if lag != 0 else veg_adjusted.values
                    
                    corr, p_value = stats.pearsonr(x, y)
                    
                    lag_correlation['statistic'].append(stat)
                    lag_correlation['climate_feature'].append(feature)
                    lag_correlation['lag'].append(lag)
                    lag_correlation['correlation'].append(corr)
                    lag_correlation['p_value'].append(p_value)
    
    return pd.DataFrame(lag_correlation)

# granger causality
def granger_causality_test(climate_df, vegetation_df, max_lag=10):
    
    results = {
        'climate_feature': [],
        'vegetation_stat': [],
        'max_lag': [],
        'min_p_value': [],
        'causality_direction': []
    }
    
    for climate_feature in climate_df.columns:
        for veg_stat in vegetation_df.columns:
            if veg_stat in statistic_corr:
                
                intersecting_idx = climate_df.index.intersection(vegetation_df.index)

                climate_series = climate_df[climate_feature].loc[intersecting_idx]
                veg_series = vegetation_df[veg_stat].loc[intersecting_idx]
                
                # data yang akan dilakukan granger test
                data = pd.DataFrame({
                    'climate': climate_series,
                    'vegetation': veg_series
                })
                
                # Test if climate Granger-causes vegetation
                try:
                    climate_to_veg = grangercausalitytests(data[['vegetation', 'climate']], 
                                                          maxlag=max_lag)

                    # print("grangertest:")
                    # print(climate_to_veg)

                    min_p_climate_to_veg = min([climate_to_veg[lag][0]['ssr_chi2test'][1] 
                                             for lag in range(1, max_lag+1)])
                    
                    # Determine causality direction
                    if min_p_climate_to_veg < 0.05:
                        direction = 'granger-causal'
                        min_p = min_p_climate_to_veg
                    else:
                        direction = 'none'
                        min_p = min(min_p_climate_to_veg, min_p_veg_to_climate)
                    
                    results['climate_feature'].append(climate_feature)
                    results['vegetation_stat'].append(veg_stat)
                    results['max_lag'].append(max_lag)
                    results['min_p_value'].append(min_p)
                    results['causality_direction'].append(direction)
                
                except Exception as e:
                    print(f"Error in Granger test: {e}")
    
    return pd.DataFrame(results)

# Visualize time series data
def plot_time_series(climate_df, vegetation_df, feature, stat):
    fig, ax1 = plt.subplots(figsize=(14, 6))
    
    # Plot climate data
    color = 'tab:blue'
    ax1.set_xlabel('Date')
    ax1.set_ylabel(feature, color=color)
    climate_series = climate_df[feature]
    ax1.plot(climate_series.index, climate_series.values, color=color, label=feature)
    ax1.tick_params(axis='y', labelcolor=color)
    
    # Create second y-axis for vegetation data
    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2.set_ylabel(f'Vegetation {stat}', color=color)
    veg_series = vegetation_df[stat]
    ax2.plot(veg_series.index, veg_series.values, color=color, label=f'Vegetation {stat}')
    ax2.tick_params(axis='y', labelcolor=color)
    
    # Add title and legend
    plt.title(f'Time Series: {feature} vs Vegetation {stat}')
    fig.tight_layout()
    fig.legend(loc="upper left", bbox_to_anchor=(0.1, 0.9))
    plt.savefig(f'{viz_dir}time_series_{feature}_{stat}.png')
    plt.close()

# Visualize lag correlation
def plot_lag_correlation(lag_corr_df, vegetation_stat, climate_feature):
    subset = lag_corr_df[(lag_corr_df['statistic'] == vegetation_stat) & 
                         (lag_corr_df['climate_feature'] == climate_feature)]
    
    plt.figure(figsize=(10, 5))
    plt.plot(subset['lag'], subset['correlation'], marker='o')
    plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)
    
    # Add significance threshold lines (assuming p<0.05)
    significant = subset[subset['p_value'] < 0.05]
    plt.scatter(significant['lag'], significant['correlation'], color='red', 
                s=80, label='p < 0.05', zorder=3)
    
    plt.title(f'Lag Correlation: {climate_feature} vs Vegetation {vegetation_stat}')
    plt.xlabel('Lag (Negative: Climate leads, Positive: Vegetation leads)')
    plt.ylabel('Correlation Coefficient')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'{viz_dir}lag_correlation_{climate_feature}_{vegetation_stat}.png')
    plt.close()

# Visualize correlation heatmap
def plot_correlation_heatmap(lag_corr_df, lag=0):
    # Filter for specific lag
    lag_subset = lag_corr_df[lag_corr_df['lag'] == lag]
    
    # Prepare data for heatmap
    pivot_data = lag_subset.pivot_table(
        index='climate_feature', 
        columns='statistic', 
        values='correlation'
    )
    
    plt.figure(figsize=(12, 8))
    
    # Create heatmap
    sns.heatmap(pivot_data, annot=True, cmap='coolwarm', center=0, 
                vmin=-1, vmax=1, fmt='.2f')
    
    plt.title(f'Correlation Heatmap (Lag = {lag})')
    plt.tight_layout()
    plt.savefig(f'{viz_dir}correlation_heatmap_lag_{lag}.png')
    plt.close()
    
    # Also create p-value heatmap
    p_value_pivot = lag_subset.pivot_table(
        index='climate_feature', 
        columns='statistic', 
        values='p_value'
    )
    
    plt.figure(figsize=(12, 8))
    sns.heatmap(p_value_pivot < 0.05, annot=p_value_pivot, cmap='viridis', 
                fmt='.3f', cbar_kws={'label': 'p-value'})
    
    plt.title(f'P-values Heatmap (Lag = {lag})')
    plt.tight_layout()
    plt.savefig(f'{viz_dir}pvalue_heatmap_lag_{lag}.png')
    plt.close()

# %%
def main():
    climate_df = load_climate_data(climate_dir, available_climate_datasets, kecamatan_names)
    vegetation_df = load_vegetation_data(vegetation_dir, available_vegetation_datasets, kecamatan_names)
    
    preprocessed_climate = {}
    preprocessed_vegetation = {}

    # lakukan preprocess pada setiap kecamatan
    for kec in kecamatan_names:
        preprocessed_climate[kec] = climate_df_processing(climate_df[kec])
        preprocessed_vegetation[kec] = vegetation_preprocessing(vegetation_df[kec])
        preprocessed_vegetation[kec] = smoothing_sg(preprocessed_vegetation[kec])

    # print(preprocessed_vegetation['warungkondang'].value_counts())
    
    # uji stasioneritas
    for kec in kecamatan_names:
        print(f"\nStationarity Test for Climate Data ({kec}):")
        climate_stationarity = test_stationarity(preprocessed_climate[kec])
        print(climate_stationarity)
        
        print(f"\nStationarity Test for Vegetation Data ({kec}):")
        vegetation_stationarity = test_stationarity(preprocessed_vegetation[kec])
        print(vegetation_stationarity)
    
    differenced_climate = {}
    differenced_vegetation = {}
    
    for kec in kecamatan_names:
        climate_stationary = test_stationarity(preprocessed_climate[kec])
        veg_stationary = test_stationarity(preprocessed_vegetation[kec])

        differenced_climate[kec] = difference_df(preprocessed_climate[kec])
        print(f"Applied differencing to climate data for {kec}")
        differenced_vegetation[kec] = difference_df(preprocessed_vegetation[kec])
        print(f"Applied differencing to vegetation data for {kec}")
    
    # adjust data agar mempunyai time series yang sama
    adjusted_data = {}
    for kec in kecamatan_names:
        intersecting_idx = differenced_climate[kec].index.intersection(differenced_vegetation[kec].index)
        adjusted_data[kec] = {
            'climate': differenced_climate[kec].loc[intersecting_idx].interpolate().bfill().ffill(),
            'vegetation': differenced_vegetation[kec].loc[intersecting_idx].interpolate().bfill().ffill()
        }
        
    # print("adjusted_data", adjusted_data)
    # hitung korelasi dengan faktor lag hingga 30
    results = {}
    for kec in kecamatan_names:
        print(f"\nLagged correlations for {kec}...")
        lag_corr_df = calculate_lagged_correlation(
            adjusted_data[kec]['climate'], 
            adjusted_data[kec]['vegetation'], 
            max_lag=30
        )
        results[kec] = lag_corr_df
    
    # cari korelasi terkuat
    for kec in kecamatan_names:
        lag_corr = results[kec]
        # ambil korelasi signifikan dan terkuat
        significant = lag_corr[lag_corr['p_value'] < 0.05]
        strongest = significant.loc[significant['correlation'].abs().sort_values(ascending=False).index]
        
        print(f"\nTop 10 strongest correlations for {kec}:")
        print(strongest.head(15))
    
    # Granger causality test
    for kec in kecamatan_names:
        print(f"\nGranger causality test for {kec}...")
        granger_results = granger_causality_test(
            adjusted_data[kec]['climate'],
            adjusted_data[kec]['vegetation']
        )
        
        # Filter for significant causal relationships
        significant_causality = granger_results[granger_results['min_p_value'] < 0.05]
        
        print(f"\nSignificant causal relationships for {kec}:")
        print(significant_causality)
    
    # 1. Time series plots for top correlations
    if len(significant) > 0:
        top_correlation = strongest.iloc[0]
        feature = top_correlation['climate_feature']
        stat = top_correlation['statistic']

        plot_time_series(
            adjusted_data[selected_kec]['climate'],
            adjusted_data[selected_kec]['vegetation'],
            feature, stat
        )
    
    # 2. Lag correlation plots
    for feature in chirts_features[:3]:  # Plot first 3 features for example
        for stat in ['mean', 'smoothed_mean']:
            plot_lag_correlation(results[selected_kec], stat, feature)
    
    # 3. Correlation heatmaps at different lags
    for lag in [-10, -5, 0, 5, 10]:
        plot_correlation_heatmap(results[selected_kec], lag)
    
    print("\nAnalysis complete! Visualization files have been saved.")

if __name__ == "__main__":
    main()
# Out:
# Stationarity Test for Climate Data (warungkondang):
#                                       ADF Statistic   p-value Stationary
# temperature_2m                             -4.92619  0.000031       True
# temperature_2m_min                        -4.226481  0.000594       True
# temperature_2m_max                        -4.818168   0.00005       True
# soil_temperature_level_1                  -4.012183  0.001348       True
# soil_temperature_level_2                  -3.425184   0.01013       True
# volumetric_soil_water_layer_1             -4.945737  0.000028       True
# volumetric_soil_water_layer_2             -4.202466  0.000653       True
# volumetric_soil_water_layer_3             -3.762532  0.003315       True
# total_precipitation_sum                    -7.75481       0.0       True
# dewpoint_temperature_2m                   -3.599118  0.005778       True
# surface_solar_radiation_downwards_sum     -7.265545       0.0       True
# surface_net_solar_radiation_sum           -7.306667       0.0       True
# total_evaporation_sum                     -7.666104       0.0       True
# u_component_of_wind_10m                   -4.792464  0.000056       True
# v_component_of_wind_10m                  -12.773807       0.0       True
# temperature_range                         -3.649748  0.004878       True
#
# Stationarity Test for Vegetation Data (warungkondang):
#               ADF Statistic   p-value Stationary
# mean              -6.085376       0.0       True
# min               -3.480235  0.008509       True
# max               -3.368081  0.012096       True
# std               -3.859685  0.002352       True
# smoothed_mean     -2.243516  0.190832      False
# smoothed_min      -3.323584  0.013857       True
# smoothed_max      -2.983049  0.036508       True
# Applied differencing to climate data for warungkondang
# Applied differencing to vegetation data for warungkondang
#
# Lagged correlations for warungkondang...
#
# Top 10 strongest correlations for warungkondang:
#      statistic                climate_feature  lag  correlation   p_value
# 731        min  volumetric_soil_water_layer_3   18     0.196344  0.000233
# 1723       std  volumetric_soil_water_layer_3   18    -0.192241  0.000316
# 693        min  volumetric_soil_water_layer_2   11     0.190586  0.000311
# 1556       std             temperature_2m_max    6     0.189893  0.000296
# 1242       max        total_precipitation_sum    2    -0.187974  0.000317
# 1685       std  volumetric_soil_water_layer_2   11    -0.180637  0.000638
# 909        min        u_component_of_wind_10m   10    -0.178421  0.000733
# 155       mean  volumetric_soil_water_layer_1    0     0.177547  0.000656
# 31        mean             temperature_2m_min    0    -0.169436  0.001156
# 1959       std              temperature_range    6     0.169362  0.001277
# 676        min  volumetric_soil_water_layer_1   25     0.160477  0.003003
# 527        min             temperature_2m_min    0    -0.159920  0.002180
# 1901       std        u_component_of_wind_10m   10     0.158143  0.002808
# 1712       std  volumetric_soil_water_layer_3    7     0.156876  0.002918
# 62        mean             temperature_2m_max    0    -0.156773  0.002669
#
# Granger causality test for warungkondang...
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3970  , p=0.2380  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.4086  , p=0.2353  , df=1
# likelihood ratio test: chi2=1.4058  , p=0.2357  , df=1
# parameter F test:         F=1.3970  , p=0.2380  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.4276  , p=0.0897  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=4.9231  , p=0.0853  , df=2
# likelihood ratio test: chi2=4.8900  , p=0.0867  , df=2
# parameter F test:         F=2.4276  , p=0.0897  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6069  , p=0.1874  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=4.9157  , p=0.1781  , df=3
# likelihood ratio test: chi2=4.8827  , p=0.1806  , df=3
# parameter F test:         F=1.6069  , p=0.1874  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1807  , p=0.3190  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.8436  , p=0.3037  , df=4
# likelihood ratio test: chi2=4.8114  , p=0.3072  , df=4
# parameter F test:         F=1.1807  , p=0.3190  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8732  , p=0.4992  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.5037  , p=0.4794  , df=5
# likelihood ratio test: chi2=4.4758  , p=0.4831  , df=5
# parameter F test:         F=0.8732  , p=0.4992  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8075  , p=0.5646  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=5.0273  , p=0.5403  , df=6
# likelihood ratio test: chi2=4.9924  , p=0.5448  , df=6
# parameter F test:         F=0.8075  , p=0.5646  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6938  , p=0.6774  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=5.0688  , p=0.6516  , df=7
# likelihood ratio test: chi2=5.0332  , p=0.6559  , df=7
# parameter F test:         F=0.6938  , p=0.6774  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6581  , p=0.7283  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=5.5280  , p=0.6999  , df=8
# likelihood ratio test: chi2=5.4856  , p=0.7046  , df=8
# parameter F test:         F=0.6581  , p=0.7283  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6385  , p=0.7640  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=6.0702  , p=0.7329  , df=9
# likelihood ratio test: chi2=6.0191  , p=0.7380  , df=9
# parameter F test:         F=0.6385  , p=0.7640  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6062  , p=0.8086  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=6.4431  , p=0.7768  , df=10
# likelihood ratio test: chi2=6.3853  , p=0.7819  , df=10
# parameter F test:         F=0.6062  , p=0.8086  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0437  , p=0.3077  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.0523  , p=0.3050  , df=1
# likelihood ratio test: chi2=1.0508  , p=0.3053  , df=1
# parameter F test:         F=1.0437  , p=0.3077  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5204  , p=0.5947  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.0553  , p=0.5900  , df=2
# likelihood ratio test: chi2=1.0538  , p=0.5904  , df=2
# parameter F test:         F=0.5204  , p=0.5947  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6757  , p=0.5674  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.0670  , p=0.5586  , df=3
# likelihood ratio test: chi2=2.0611  , p=0.5598  , df=3
# parameter F test:         F=0.6757  , p=0.5674  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5301  , p=0.7137  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.1747  , p=0.7037  , df=4
# likelihood ratio test: chi2=2.1682  , p=0.7049  , df=4
# parameter F test:         F=0.5301  , p=0.7137  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4788  , p=0.7921  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.4695  , p=0.7811  , df=5
# likelihood ratio test: chi2=2.4610  , p=0.7824  , df=5
# parameter F test:         F=0.4788  , p=0.7921  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5606  , p=0.7616  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=3.4898  , p=0.7453  , df=6
# likelihood ratio test: chi2=3.4730  , p=0.7476  , df=6
# parameter F test:         F=0.5606  , p=0.7616  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6336  , p=0.7281  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=4.6293  , p=0.7051  , df=7
# likelihood ratio test: chi2=4.5996  , p=0.7087  , df=7
# parameter F test:         F=0.6336  , p=0.7281  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5986  , p=0.7790  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=5.0281  , p=0.7546  , df=8
# likelihood ratio test: chi2=4.9930  , p=0.7583  , df=8
# parameter F test:         F=0.5986  , p=0.7790  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6827  , p=0.7246  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=6.4905  , p=0.6900  , df=9
# likelihood ratio test: chi2=6.4320  , p=0.6960  , df=9
# parameter F test:         F=0.6827  , p=0.7246  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7162  , p=0.7093  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=7.6121  , p=0.6667  , df=10
# likelihood ratio test: chi2=7.5316  , p=0.6745  , df=10
# parameter F test:         F=0.7162  , p=0.7093  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3004  , p=0.5840  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.3029  , p=0.5821  , df=1
# likelihood ratio test: chi2=0.3028  , p=0.5821  , df=1
# parameter F test:         F=0.3004  , p=0.5840  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1725  , p=0.8417  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.3498  , p=0.8396  , df=2
# likelihood ratio test: chi2=0.3496  , p=0.8396  , df=2
# parameter F test:         F=0.1725  , p=0.8417  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2437  , p=0.8658  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=0.7455  , p=0.8625  , df=3
# likelihood ratio test: chi2=0.7447  , p=0.8626  , df=3
# parameter F test:         F=0.2437  , p=0.8658  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1996  , p=0.9385  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=0.8187  , p=0.9359  , df=4
# likelihood ratio test: chi2=0.8178  , p=0.9360  , df=4
# parameter F test:         F=0.1996  , p=0.9385  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.1756  , p=0.9716  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=0.9056  , p=0.9698  , df=5
# likelihood ratio test: chi2=0.9044  , p=0.9699  , df=5
# parameter F test:         F=0.1756  , p=0.9716  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1784  , p=0.9826  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=1.1108  , p=0.9811  , df=6
# likelihood ratio test: chi2=1.1091  , p=0.9811  , df=6
# parameter F test:         F=0.1784  , p=0.9826  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2296  , p=0.9781  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=1.6772  , p=0.9755  , df=7
# likelihood ratio test: chi2=1.6733  , p=0.9757  , df=7
# parameter F test:         F=0.2296  , p=0.9781  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2353  , p=0.9841  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=1.9761  , p=0.9817  , df=8
# likelihood ratio test: chi2=1.9707  , p=0.9819  , df=8
# parameter F test:         F=0.2353  , p=0.9841  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.2235  , p=0.9910  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=2.1250  , p=0.9893  , df=9
# likelihood ratio test: chi2=2.1187  , p=0.9894  , df=9
# parameter F test:         F=0.2235  , p=0.9910  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.2256  , p=0.9938  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=2.3983  , p=0.9923  , df=10
# likelihood ratio test: chi2=2.3902  , p=0.9924  , df=10
# parameter F test:         F=0.2256  , p=0.9938  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8863  , p=0.3471  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.8937  , p=0.3445  , df=1
# likelihood ratio test: chi2=0.8926  , p=0.3448  , df=1
# parameter F test:         F=0.8863  , p=0.3471  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4402  , p=0.6443  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.8926  , p=0.6400  , df=2
# likelihood ratio test: chi2=0.8915  , p=0.6403  , df=2
# parameter F test:         F=0.4402  , p=0.6443  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4457  , p=0.7205  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.3635  , p=0.7141  , df=3
# likelihood ratio test: chi2=1.3610  , p=0.7147  , df=3
# parameter F test:         F=0.4457  , p=0.7205  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5520  , p=0.6977  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.2646  , p=0.6872  , df=4
# likelihood ratio test: chi2=2.2575  , p=0.6885  , df=4
# parameter F test:         F=0.5520  , p=0.6977  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4377  , p=0.8221  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.2575  , p=0.8125  , df=5
# likelihood ratio test: chi2=2.2504  , p=0.8135  , df=5
# parameter F test:         F=0.4377  , p=0.8221  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7754  , p=0.5897  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=4.8272  , p=0.5662  , df=6
# likelihood ratio test: chi2=4.7951  , p=0.5704  , df=6
# parameter F test:         F=0.7754  , p=0.5897  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6576  , p=0.7079  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=4.8047  , p=0.6838  , df=7
# likelihood ratio test: chi2=4.7728  , p=0.6877  , df=7
# parameter F test:         F=0.6576  , p=0.7079  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0244  , p=0.4171  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=8.6054  , p=0.3767  , df=8
# likelihood ratio test: chi2=8.5033  , p=0.3859  , df=8
# parameter F test:         F=1.0244  , p=0.4171  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0636  , p=0.3893  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=10.1123 , p=0.3415  , df=9
# likelihood ratio test: chi2=9.9714  , p=0.3528  , df=9
# parameter F test:         F=1.0636  , p=0.3893  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9978  , p=0.4450  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=10.6048 , p=0.3891  , df=10
# likelihood ratio test: chi2=10.4495 , p=0.4020  , df=10
# parameter F test:         F=0.9978  , p=0.4450  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0602  , p=0.8064  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0607  , p=0.8054  , df=1
# likelihood ratio test: chi2=0.0607  , p=0.8054  , df=1
# parameter F test:         F=0.0602  , p=0.8064  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4724  , p=0.6239  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.9580  , p=0.6194  , df=2
# likelihood ratio test: chi2=0.9568  , p=0.6198  , df=2
# parameter F test:         F=0.4724  , p=0.6239  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9101  , p=0.4362  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.7841  , p=0.4261  , df=3
# likelihood ratio test: chi2=2.7734  , p=0.4279  , df=3
# parameter F test:         F=0.9101  , p=0.4362  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6640  , p=0.6174  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.7240  , p=0.6050  , df=4
# likelihood ratio test: chi2=2.7138  , p=0.6068  , df=4
# parameter F test:         F=0.6640  , p=0.6174  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6348  , p=0.6733  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.2741  , p=0.6578  , df=5
# likelihood ratio test: chi2=3.2593  , p=0.6601  , df=5
# parameter F test:         F=0.6348  , p=0.6733  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5956  , p=0.7339  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=3.7078  , p=0.7162  , df=6
# likelihood ratio test: chi2=3.6888  , p=0.7187  , df=6
# parameter F test:         F=0.5956  , p=0.7339  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5230  , p=0.8171  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=3.8212  , p=0.8001  , df=7
# likelihood ratio test: chi2=3.8009  , p=0.8024  , df=7
# parameter F test:         F=0.5230  , p=0.8171  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7931  , p=0.0773  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=15.0623 , p=0.0579  , df=8
# likelihood ratio test: chi2=14.7532 , p=0.0641  , df=8
# parameter F test:         F=1.7931  , p=0.0773  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6934  , p=0.0893  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=16.1002 , p=0.0648  , df=9
# likelihood ratio test: chi2=15.7468 , p=0.0724  , df=9
# parameter F test:         F=1.6934  , p=0.0893  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8375  , p=0.0533  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=19.5299 , p=0.0340  , df=10
# likelihood ratio test: chi2=19.0116 , p=0.0401  , df=10
# parameter F test:         F=1.8375  , p=0.0533  , df_denom=334, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.2720  , p=0.0222  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=5.3158  , p=0.0211  , df=1
# likelihood ratio test: chi2=5.2774  , p=0.0216  , df=1
# parameter F test:         F=5.2720  , p=0.0222  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.7455  , p=0.0092  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=9.6236  , p=0.0081  , df=2
# likelihood ratio test: chi2=9.4983  , p=0.0087  , df=2
# parameter F test:         F=4.7455  , p=0.0092  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1684  , p=0.0245  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=9.6926  , p=0.0214  , df=3
# likelihood ratio test: chi2=9.5651  , p=0.0226  , df=3
# parameter F test:         F=3.1684  , p=0.0245  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3466  , p=0.0542  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=9.6266  , p=0.0472  , df=4
# likelihood ratio test: chi2=9.5004  , p=0.0497  , df=4
# parameter F test:         F=2.3466  , p=0.0542  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6816  , p=0.1383  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=8.6729  , p=0.1228  , df=5
# likelihood ratio test: chi2=8.5701  , p=0.1275  , df=5
# parameter F test:         F=1.6816  , p=0.1383  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3446  , p=0.2366  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=8.3710  , p=0.2122  , df=6
# likelihood ratio test: chi2=8.2749  , p=0.2186  , df=6
# parameter F test:         F=1.3446  , p=0.2366  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5316  , p=0.1554  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=11.1904 , p=0.1305  , df=7
# likelihood ratio test: chi2=11.0191 , p=0.1378  , df=7
# parameter F test:         F=1.5316  , p=0.1554  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3312  , p=0.2268  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=11.1820 , p=0.1916  , df=8
# likelihood ratio test: chi2=11.0104 , p=0.2011  , df=8
# parameter F test:         F=1.3312  , p=0.2268  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6423  , p=0.1021  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=15.6138 , p=0.0754  , df=9
# likelihood ratio test: chi2=15.2811 , p=0.0835  , df=9
# parameter F test:         F=1.6423  , p=0.1021  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.6473  , p=0.0921  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=17.5086 , p=0.0638  , df=10
# likelihood ratio test: chi2=17.0905 , p=0.0724  , df=10
# parameter F test:         F=1.6473  , p=0.0921  , df_denom=334, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4548  , p=0.2285  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.4669  , p=0.2258  , df=1
# likelihood ratio test: chi2=1.4640  , p=0.2263  , df=1
# parameter F test:         F=1.4548  , p=0.2285  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8437  , p=0.4310  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.7109  , p=0.4251  , df=2
# likelihood ratio test: chi2=1.7069  , p=0.4259  , df=2
# parameter F test:         F=0.8437  , p=0.4310  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6313  , p=0.5952  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.9311  , p=0.5868  , df=3
# likelihood ratio test: chi2=1.9260  , p=0.5879  , df=3
# parameter F test:         F=0.6313  , p=0.5952  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4737  , p=0.7550  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=1.9433  , p=0.7462  , df=4
# likelihood ratio test: chi2=1.9381  , p=0.7471  , df=4
# parameter F test:         F=0.4737  , p=0.7550  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4395  , p=0.8208  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.2670  , p=0.8111  , df=5
# likelihood ratio test: chi2=2.2599  , p=0.8121  , df=5
# parameter F test:         F=0.4395  , p=0.8208  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3900  , p=0.8853  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=2.4279  , p=0.8765  , df=6
# likelihood ratio test: chi2=2.4197  , p=0.8773  , df=6
# parameter F test:         F=0.3900  , p=0.8853  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5946  , p=0.7603  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=4.3445  , p=0.7394  , df=7
# likelihood ratio test: chi2=4.3183  , p=0.7425  , df=7
# parameter F test:         F=0.5946  , p=0.7603  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5173  , p=0.8434  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=4.3457  , p=0.8247  , df=8
# likelihood ratio test: chi2=4.3194  , p=0.8272  , df=8
# parameter F test:         F=0.5173  , p=0.8434  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5897  , p=0.8056  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=5.6062  , p=0.7786  , df=9
# likelihood ratio test: chi2=5.5625  , p=0.7828  , df=9
# parameter F test:         F=0.5897  , p=0.8056  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6305  , p=0.7876  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=6.7017  , p=0.7533  , df=10
# likelihood ratio test: chi2=6.6392  , p=0.7590  , df=10
# parameter F test:         F=0.6305  , p=0.7876  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1645  , p=0.6853  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.1659  , p=0.6838  , df=1
# likelihood ratio test: chi2=0.1658  , p=0.6838  , df=1
# parameter F test:         F=0.1645  , p=0.6853  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9240  , p=0.1475  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=3.9017  , p=0.1422  , df=2
# likelihood ratio test: chi2=3.8809  , p=0.1436  , df=2
# parameter F test:         F=1.9240  , p=0.1475  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3348  , p=0.2628  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=4.0833  , p=0.2526  , df=3
# likelihood ratio test: chi2=4.0605  , p=0.2550  , df=3
# parameter F test:         F=1.3348  , p=0.2628  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0123  , p=0.4009  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.1529  , p=0.3857  , df=4
# likelihood ratio test: chi2=4.1292  , p=0.3888  , df=4
# parameter F test:         F=1.0123  , p=0.4009  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7961  , p=0.5530  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.1062  , p=0.5342  , df=5
# likelihood ratio test: chi2=4.0830  , p=0.5375  , df=5
# parameter F test:         F=0.7961  , p=0.5530  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6457  , p=0.6936  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=4.0197  , p=0.6740  , df=6
# likelihood ratio test: chi2=3.9974  , p=0.6770  , df=6
# parameter F test:         F=0.6457  , p=0.6936  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6567  , p=0.7087  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=4.7981  , p=0.6846  , df=7
# likelihood ratio test: chi2=4.7663  , p=0.6885  , df=7
# parameter F test:         F=0.6567  , p=0.7087  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5700  , p=0.8024  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=4.7884  , p=0.7799  , df=8
# likelihood ratio test: chi2=4.7566  , p=0.7833  , df=8
# parameter F test:         F=0.5700  , p=0.8024  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5245  , p=0.8566  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=4.9869  , p=0.8354  , df=9
# likelihood ratio test: chi2=4.9523  , p=0.8384  , df=9
# parameter F test:         F=0.5245  , p=0.8566  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4597  , p=0.9151  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=4.8856  , p=0.8987  , df=10
# likelihood ratio test: chi2=4.8523  , p=0.9008  , df=10
# parameter F test:         F=0.4597  , p=0.9151  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9120  , p=0.3402  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.9196  , p=0.3376  , df=1
# likelihood ratio test: chi2=0.9184  , p=0.3379  , df=1
# parameter F test:         F=0.9120  , p=0.3402  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7087  , p=0.4930  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.4372  , p=0.4874  , df=2
# likelihood ratio test: chi2=1.4343  , p=0.4881  , df=2
# parameter F test:         F=0.7087  , p=0.4930  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4815  , p=0.6954  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.4729  , p=0.6885  , df=3
# likelihood ratio test: chi2=1.4699  , p=0.6892  , df=3
# parameter F test:         F=0.4815  , p=0.6954  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4790  , p=0.7511  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=1.9652  , p=0.7422  , df=4
# likelihood ratio test: chi2=1.9599  , p=0.7431  , df=4
# parameter F test:         F=0.4790  , p=0.7511  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3607  , p=0.8752  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=1.8601  , p=0.8681  , df=5
# likelihood ratio test: chi2=1.8553  , p=0.8688  , df=5
# parameter F test:         F=0.3607  , p=0.8752  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2984  , p=0.9374  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=1.8580  , p=0.9323  , df=6
# likelihood ratio test: chi2=1.8532  , p=0.9327  , df=6
# parameter F test:         F=0.2984  , p=0.9374  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2535  , p=0.9709  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=1.8520  , p=0.9676  , df=7
# likelihood ratio test: chi2=1.8472  , p=0.9678  , df=7
# parameter F test:         F=0.2535  , p=0.9709  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2921  , p=0.9684  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=2.4539  , p=0.9638  , df=8
# likelihood ratio test: chi2=2.4455  , p=0.9642  , df=8
# parameter F test:         F=0.2921  , p=0.9684  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3249  , p=0.9666  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=3.0891  , p=0.9607  , df=9
# likelihood ratio test: chi2=3.0757  , p=0.9612  , df=9
# parameter F test:         F=0.3249  , p=0.9666  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.2737  , p=0.9865  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=2.9095  , p=0.9835  , df=10
# likelihood ratio test: chi2=2.8976  , p=0.9837  , df=10
# parameter F test:         F=0.2737  , p=0.9865  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6434  , p=0.1049  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=2.6654  , p=0.1026  , df=1
# likelihood ratio test: chi2=2.6557  , p=0.1032  , df=1
# parameter F test:         F=2.6434  , p=0.1049  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6107  , p=0.2012  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=3.2664  , p=0.1953  , df=2
# likelihood ratio test: chi2=3.2518  , p=0.1967  , df=2
# parameter F test:         F=1.6107  , p=0.2012  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2268  , p=0.2998  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.7529  , p=0.2894  , df=3
# likelihood ratio test: chi2=3.7336  , p=0.2917  , df=3
# parameter F test:         F=1.2268  , p=0.2998  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0248  , p=0.3943  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.2040  , p=0.3791  , df=4
# likelihood ratio test: chi2=4.1797  , p=0.3822  , df=4
# parameter F test:         F=1.0248  , p=0.3943  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8093  , p=0.5436  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.1742  , p=0.5246  , df=5
# likelihood ratio test: chi2=4.1502  , p=0.5280  , df=5
# parameter F test:         F=0.8093  , p=0.5436  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6035  , p=0.7275  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=3.7571  , p=0.7095  , df=6
# likelihood ratio test: chi2=3.7376  , p=0.7121  , df=6
# parameter F test:         F=0.6035  , p=0.7275  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5954  , p=0.7596  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=4.3503  , p=0.7387  , df=7
# likelihood ratio test: chi2=4.3241  , p=0.7418  , df=7
# parameter F test:         F=0.5954  , p=0.7596  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.2044  , p=0.0267  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=18.5169 , p=0.0177  , df=8
# likelihood ratio test: chi2=18.0526 , p=0.0208  , df=8
# parameter F test:         F=2.2044  , p=0.0267  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9829  , p=0.0405  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=18.8524 , p=0.0265  , df=9
# likelihood ratio test: chi2=18.3702 , p=0.0311  , df=9
# parameter F test:         F=1.9829  , p=0.0405  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.0191  , p=0.0308  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=21.4605 , p=0.0181  , df=10
# likelihood ratio test: chi2=20.8368 , p=0.0223  , df=10
# parameter F test:         F=2.0191  , p=0.0308  , df_denom=334, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3303  , p=0.5658  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.3331  , p=0.5638  , df=1
# likelihood ratio test: chi2=0.3329  , p=0.5639  , df=1
# parameter F test:         F=0.3303  , p=0.5658  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3356  , p=0.2643  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.7086  , p=0.2581  , df=2
# likelihood ratio test: chi2=2.6985  , p=0.2594  , df=2
# parameter F test:         F=1.3356  , p=0.2643  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0728  , p=0.3606  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.2820  , p=0.3502  , df=3
# likelihood ratio test: chi2=3.2672  , p=0.3522  , df=3
# parameter F test:         F=1.0728  , p=0.3606  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2551  , p=0.2874  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=5.1487  , p=0.2724  , df=4
# likelihood ratio test: chi2=5.1123  , p=0.2760  , df=4
# parameter F test:         F=1.2551  , p=0.2874  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0568  , p=0.3842  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=5.4507  , p=0.3634  , df=5
# likelihood ratio test: chi2=5.4098  , p=0.3679  , df=5
# parameter F test:         F=1.0568  , p=0.3842  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4905  , p=0.1804  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=9.2788  , p=0.1585  , df=6
# likelihood ratio test: chi2=9.1609  , p=0.1647  , df=6
# parameter F test:         F=1.4905  , p=0.1804  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6067  , p=0.1324  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=11.7385 , p=0.1095  , df=7
# likelihood ratio test: chi2=11.5502 , p=0.1164  , df=7
# parameter F test:         F=1.6067  , p=0.1324  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4134  , p=0.1895  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=11.8723 , p=0.1570  , df=8
# likelihood ratio test: chi2=11.6791 , p=0.1661  , df=8
# parameter F test:         F=1.4134  , p=0.1895  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3277  , p=0.2211  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=12.6232 , p=0.1804  , df=9
# likelihood ratio test: chi2=12.4046 , p=0.1914  , df=9
# parameter F test:         F=1.3277  , p=0.2211  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2684  , p=0.2471  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=13.4815 , p=0.1980  , df=10
# likelihood ratio test: chi2=13.2318 , p=0.2110  , df=10
# parameter F test:         F=1.2684  , p=0.2471  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2139  , p=0.2713  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.2240  , p=0.2686  , df=1
# likelihood ratio test: chi2=1.2219  , p=0.2690  , df=1
# parameter F test:         F=1.2139  , p=0.2713  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2481  , p=0.2883  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.5310  , p=0.2821  , df=2
# likelihood ratio test: chi2=2.5222  , p=0.2833  , df=2
# parameter F test:         F=1.2481  , p=0.2883  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1154  , p=0.3428  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.4122  , p=0.3323  , df=3
# likelihood ratio test: chi2=3.3962  , p=0.3345  , df=3
# parameter F test:         F=1.1154  , p=0.3428  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9476  , p=0.4365  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=3.8871  , p=0.4215  , df=4
# likelihood ratio test: chi2=3.8664  , p=0.4244  , df=4
# parameter F test:         F=0.9476  , p=0.4365  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7653  , p=0.5753  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.9470  , p=0.5571  , df=5
# likelihood ratio test: chi2=3.9255  , p=0.5602  , df=5
# parameter F test:         F=0.7653  , p=0.5753  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0963  , p=0.0531  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=13.0501 , p=0.0422  , df=6
# likelihood ratio test: chi2=12.8185 , p=0.0460  , df=6
# parameter F test:         F=2.0963  , p=0.0531  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8004  , p=0.0862  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=13.1536 , p=0.0685  , df=7
# likelihood ratio test: chi2=12.9177 , p=0.0741  , df=7
# parameter F test:         F=1.8004  , p=0.0862  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5757  , p=0.1308  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=13.2358 , p=0.1040  , df=8
# likelihood ratio test: chi2=12.9963 , p=0.1120  , df=8
# parameter F test:         F=1.5757  , p=0.1308  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.8815  , p=0.0538  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=17.8885 , p=0.0365  , df=9
# likelihood ratio test: chi2=17.4535 , p=0.0421  , df=9
# parameter F test:         F=1.8815  , p=0.0538  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.1909  , p=0.0180  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=23.2868 , p=0.0097  , df=10
# likelihood ratio test: chi2=22.5549 , p=0.0125  , df=10
# parameter F test:         F=2.1909  , p=0.0180  , df_denom=334, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0896  , p=0.7649  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0903  , p=0.7638  , df=1
# likelihood ratio test: chi2=0.0903  , p=0.7638  , df=1
# parameter F test:         F=0.0896  , p=0.7649  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2132  , p=0.8081  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.4323  , p=0.8056  , df=2
# likelihood ratio test: chi2=0.4320  , p=0.8057  , df=2
# parameter F test:         F=0.2132  , p=0.8081  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1670  , p=0.9186  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=0.5108  , p=0.9165  , df=3
# likelihood ratio test: chi2=0.5105  , p=0.9166  , df=3
# parameter F test:         F=0.1670  , p=0.9186  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5023  , p=0.7341  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.0607  , p=0.7246  , df=4
# likelihood ratio test: chi2=2.0548  , p=0.7257  , df=4
# parameter F test:         F=0.5023  , p=0.7341  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4763  , p=0.7939  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.4564  , p=0.7830  , df=5
# likelihood ratio test: chi2=2.4481  , p=0.7843  , df=5
# parameter F test:         F=0.4763  , p=0.7939  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6006  , p=0.7298  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=3.7393  , p=0.7119  , df=6
# likelihood ratio test: chi2=3.7199  , p=0.7145  , df=6
# parameter F test:         F=0.6006  , p=0.7298  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5127  , p=0.8249  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=3.7458  , p=0.8085  , df=7
# likelihood ratio test: chi2=3.7264  , p=0.8107  , df=7
# parameter F test:         F=0.5127  , p=0.8249  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7523  , p=0.6452  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=6.3193  , p=0.6115  , df=8
# likelihood ratio test: chi2=6.2640  , p=0.6177  , df=8
# parameter F test:         F=0.7523  , p=0.6452  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7744  , p=0.6402  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=7.3629  , p=0.5994  , df=9
# likelihood ratio test: chi2=7.2878  , p=0.6072  , df=9
# parameter F test:         F=0.7744  , p=0.6402  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8266  , p=0.6032  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=8.7860  , p=0.5525  , df=10
# likelihood ratio test: chi2=8.6791  , p=0.5628  , df=10
# parameter F test:         F=0.8266  , p=0.6032  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1934  , p=0.2754  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.2034  , p=0.2727  , df=1
# likelihood ratio test: chi2=1.2014  , p=0.2730  , df=1
# parameter F test:         F=1.1934  , p=0.2754  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1528  , p=0.3169  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.3379  , p=0.3107  , df=2
# likelihood ratio test: chi2=2.3304  , p=0.3119  , df=2
# parameter F test:         F=1.1528  , p=0.3169  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1095  , p=0.3452  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.3941  , p=0.3348  , df=3
# likelihood ratio test: chi2=3.3783  , p=0.3369  , df=3
# parameter F test:         F=1.1095  , p=0.3452  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9332  , p=0.4447  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=3.8282  , p=0.4297  , df=4
# likelihood ratio test: chi2=3.8081  , p=0.4326  , df=4
# parameter F test:         F=0.9332  , p=0.4447  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7511  , p=0.5857  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.8739  , p=0.5677  , df=5
# likelihood ratio test: chi2=3.8532  , p=0.5707  , df=5
# parameter F test:         F=0.7511  , p=0.5857  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.3712  , p=0.0030  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=20.9871 , p=0.0018  , df=6
# likelihood ratio test: chi2=20.3966 , p=0.0024  , df=6
# parameter F test:         F=3.3712  , p=0.0030  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9839  , p=0.0047  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=21.8008 , p=0.0027  , df=7
# likelihood ratio test: chi2=21.1628 , p=0.0035  , df=7
# parameter F test:         F=2.9839  , p=0.0047  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.7662  , p=0.0057  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=23.2363 , p=0.0031  , df=8
# likelihood ratio test: chi2=22.5114 , p=0.0041  , df=8
# parameter F test:         F=2.7662  , p=0.0057  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7785  , p=0.0038  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=26.4160 , p=0.0017  , df=9
# likelihood ratio test: chi2=25.4819 , p=0.0025  , df=9
# parameter F test:         F=2.7785  , p=0.0038  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.7679  , p=0.0027  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=29.4192 , p=0.0011  , df=10
# likelihood ratio test: chi2=28.2636 , p=0.0016  , df=10
# parameter F test:         F=2.7679  , p=0.0027  , df_denom=334, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6530  , p=0.4196  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.6584  , p=0.4171  , df=1
# likelihood ratio test: chi2=0.6578  , p=0.4173  , df=1
# parameter F test:         F=0.6530  , p=0.4196  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4581  , p=0.6329  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.9289  , p=0.6285  , df=2
# likelihood ratio test: chi2=0.9277  , p=0.6288  , df=2
# parameter F test:         F=0.4581  , p=0.6329  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4138  , p=0.2385  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=4.3249  , p=0.2284  , df=3
# likelihood ratio test: chi2=4.2993  , p=0.2309  , df=3
# parameter F test:         F=1.4138  , p=0.2385  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1373  , p=0.3387  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.6656  , p=0.3234  , df=4
# likelihood ratio test: chi2=4.6357  , p=0.3268  , df=4
# parameter F test:         F=1.1373  , p=0.3387  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6517  , p=0.6604  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.3613  , p=0.6445  , df=5
# likelihood ratio test: chi2=3.3457  , p=0.6469  , df=5
# parameter F test:         F=0.6517  , p=0.6604  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9446  , p=0.4630  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=5.8805  , p=0.4367  , df=6
# likelihood ratio test: chi2=5.8329  , p=0.4422  , df=6
# parameter F test:         F=0.9446  , p=0.4630  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ...
# likelihood ratio test: chi2=18.3465 , p=0.0494  , df=10
# parameter F test:         F=1.7715  , p=0.0647  , df_denom=334, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0145  , p=0.9044  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0146  , p=0.9039  , df=1
# likelihood ratio test: chi2=0.0146  , p=0.9039  , df=1
# parameter F test:         F=0.0145  , p=0.9044  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2203  , p=0.8024  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.4467  , p=0.7998  , df=2
# likelihood ratio test: chi2=0.4464  , p=0.8000  , df=2
# parameter F test:         F=0.2203  , p=0.8024  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1740  , p=0.9139  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=0.5324  , p=0.9117  , df=3
# likelihood ratio test: chi2=0.5320  , p=0.9118  , df=3
# parameter F test:         F=0.1740  , p=0.9139  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2400  , p=0.9156  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=0.9844  , p=0.9121  , df=4
# likelihood ratio test: chi2=0.9831  , p=0.9124  , df=4
# parameter F test:         F=0.2400  , p=0.9156  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2401  , p=0.9446  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=1.2381  , p=0.9412  , df=5
# likelihood ratio test: chi2=1.2360  , p=0.9414  , df=5
# parameter F test:         F=0.2401  , p=0.9446  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0308  , p=0.4049  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=6.4171  , p=0.3781  , df=6
# likelihood ratio test: chi2=6.3605  , p=0.3840  , df=6
# parameter F test:         F=1.0308  , p=0.4049  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0558  , p=0.3919  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.7138  , p=0.3585  , df=7
# likelihood ratio test: chi2=7.6319  , p=0.3662  , df=7
# parameter F test:         F=1.0558  , p=0.3919  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9472  , p=0.4776  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=7.9565  , p=0.4377  , df=8
# likelihood ratio test: chi2=7.8691  , p=0.4464  , df=8
# parameter F test:         F=0.9472  , p=0.4776  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6293  , p=0.1056  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=15.4907 , p=0.0783  , df=9
# likelihood ratio test: chi2=15.1631 , p=0.0866  , df=9
# parameter F test:         F=1.6293  , p=0.1056  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.6941  , p=0.0808  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=18.0057 , p=0.0549  , df=10
# likelihood ratio test: chi2=17.5639 , p=0.0628  , df=10
# parameter F test:         F=1.6941  , p=0.0808  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0007  , p=0.9791  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0007  , p=0.9790  , df=1
# likelihood ratio test: chi2=0.0007  , p=0.9790  , df=1
# parameter F test:         F=0.0007  , p=0.9791  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9023  , p=0.1507  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=3.8578  , p=0.1453  , df=2
# likelihood ratio test: chi2=3.8374  , p=0.1468  , df=2
# parameter F test:         F=1.9023  , p=0.1507  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3748  , p=0.2502  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=4.2058  , p=0.2401  , df=3
# likelihood ratio test: chi2=4.1816  , p=0.2425  , df=3
# parameter F test:         F=1.3748  , p=0.2502  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5766  , p=0.1800  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=6.4676  , p=0.1668  , df=4
# likelihood ratio test: chi2=6.4103  , p=0.1705  , df=4
# parameter F test:         F=1.5766  , p=0.1800  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3167  , p=0.2563  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=6.7912  , p=0.2366  , df=5
# likelihood ratio test: chi2=6.7279  , p=0.2417  , df=5
# parameter F test:         F=1.3167  , p=0.2563  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3682  , p=0.2266  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=8.5179  , p=0.2026  , df=6
# likelihood ratio test: chi2=8.4184  , p=0.2090  , df=6
# parameter F test:         F=1.3682  , p=0.2266  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2411  , p=0.2794  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=9.0678  , p=0.2478  , df=7
# likelihood ratio test: chi2=8.9549  , p=0.2559  , df=7
# parameter F test:         F=1.2411  , p=0.2794  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3079  , p=0.2383  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=10.9867 , p=0.2025  , df=8
# likelihood ratio test: chi2=10.8210 , p=0.2120  , df=8
# parameter F test:         F=1.3079  , p=0.2383  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2689  , p=0.2527  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=12.0636 , p=0.2097  , df=9
# likelihood ratio test: chi2=11.8637 , p=0.2211  , df=9
# parameter F test:         F=1.2689  , p=0.2527  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1385  , p=0.3325  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=12.1006 , p=0.2784  , df=10
# likelihood ratio test: chi2=11.8989 , p=0.2919  , df=10
# parameter F test:         F=1.1385  , p=0.3325  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0842  , p=0.7718  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0849  , p=0.7707  , df=1
# likelihood ratio test: chi2=0.0849  , p=0.7708  , df=1
# parameter F test:         F=0.0842  , p=0.7718  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1302  , p=0.8780  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.2640  , p=0.8763  , df=2
# likelihood ratio test: chi2=0.2639  , p=0.8764  , df=2
# parameter F test:         F=0.1302  , p=0.8780  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1862  , p=0.9058  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=0.5696  , p=0.9033  , df=3
# likelihood ratio test: chi2=0.5692  , p=0.9035  , df=3
# parameter F test:         F=0.1862  , p=0.9058  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1395  , p=0.9675  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=0.5723  , p=0.9661  , df=4
# likelihood ratio test: chi2=0.5719  , p=0.9661  , df=4
# parameter F test:         F=0.1395  , p=0.9675  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.1256  , p=0.9866  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=0.6478  , p=0.9857  , df=5
# likelihood ratio test: chi2=0.6472  , p=0.9857  , df=5
# parameter F test:         F=0.1256  , p=0.9866  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0174  , p=0.0627  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=12.5594 , p=0.0506  , df=6
# likelihood ratio test: chi2=12.3447 , p=0.0547  , df=6
# parameter F test:         F=2.0174  , p=0.0627  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7581  , p=0.0948  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=12.8447 , p=0.0760  , df=7
# likelihood ratio test: chi2=12.6197 , p=0.0819  , df=7
# parameter F test:         F=1.7581  , p=0.0948  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6107  , p=0.1204  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=13.5298 , p=0.0949  , df=8
# likelihood ratio test: chi2=13.2797 , p=0.1026  , df=8
# parameter F test:         F=1.6107  , p=0.1204  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9535  , p=0.0440  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=18.5732 , p=0.0291  , df=9
# likelihood ratio test: chi2=18.1049 , p=0.0340  , df=9
# parameter F test:         F=1.9535  , p=0.0440  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9506  , p=0.0380  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=20.7327 , p=0.0230  , df=10
# likelihood ratio test: chi2=20.1498 , p=0.0279  , df=10
# parameter F test:         F=1.9506  , p=0.0380  , df_denom=334, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.6655  , p=0.0563  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=3.6959  , p=0.0545  , df=1
# likelihood ratio test: chi2=3.6773  , p=0.0552  , df=1
# parameter F test:         F=3.6655  , p=0.0563  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.4375  , p=0.0888  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=4.9430  , p=0.0845  , df=2
# likelihood ratio test: chi2=4.9097  , p=0.0859  , df=2
# parameter F test:         F=2.4375  , p=0.0888  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2027  , p=0.0875  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=6.7383  , p=0.0807  , df=3
# likelihood ratio test: chi2=6.6763  , p=0.0830  , df=3
# parameter F test:         F=2.2027  , p=0.0875  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8580  , p=0.1173  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=7.6219  , p=0.1065  , df=4
# likelihood ratio test: chi2=7.5425  , p=0.1098  , df=4
# parameter F test:         F=1.8580  , p=0.1173  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0370  , p=0.3956  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=5.3485  , p=0.3748  , df=5
# likelihood ratio test: chi2=5.3091  , p=0.3793  , df=5
# parameter F test:         F=1.0370  , p=0.3956  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2316  , p=0.2894  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=7.6671  , p=0.2635  , df=6
# likelihood ratio test: chi2=7.5864  , p=0.2700  , df=6
# parameter F test:         F=1.2316  , p=0.2894  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9797  , p=0.4458  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.1578  , p=0.4126  , df=7
# likelihood ratio test: chi2=7.0872  , p=0.4199  , df=7
# parameter F test:         F=0.9797  , p=0.4458  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8636  , p=0.5475  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=7.2545  , p=0.5094  , df=8
# likelihood ratio test: chi2=7.1818  , p=0.5172  , df=8
# parameter F test:         F=0.8636  , p=0.5475  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9119  , p=0.5149  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=8.6699  , p=0.4683  , df=9
# likelihood ratio test: chi2=8.5660  , p=0.4783  , df=9
# parameter F test:         F=0.9119  , p=0.5149  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8611  , p=0.5701  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=9.1525  , p=0.5177  , df=10
# likelihood ratio test: chi2=9.0365  , p=0.5286  , df=10
# parameter F test:         F=0.8611  , p=0.5701  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Significant causal relationships for warungkondang:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 106
#     103     print("\nAnalysis complete! Visualization files have been saved.")
#     105 if __name__ == "__main__":
# --> 106     main()
#
# Cell In[63], line 101, in main()
#      99 # 3. Correlation heatmaps at different lags
#     100 for lag in [-10, -5, 0, 5, 10]:
# --> 101     plot_correlation_heatmap(results[selected_kec], lag)
#     103 print("\nAnalysis complete! Visualization files have been saved.")
#
# Cell In[62], line 254, in plot_correlation_heatmap(lag_corr_df, lag)
#     247 p_value_pivot = lag_subset.pivot_table(
#     248     index='climate_feature',
#     249     columns='statistic',
#     250     values='p_value'
#     251 )
#     253 plt.figure(figsize=(12, 8))
# --> 254 sns.heatmap(p_value_pivot < 0.05, annot=p_value_pivot, cmap='viridis',
#     255             fmt='.3f', cbar_kws={'label': 'p-value'})
#     257 plt.title(f'P-values Heatmap (Lag = {lag})')
#     258 plt.tight_layout()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/seaborn/matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/seaborn/matrix.py:202, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     200         vmin = np.nanpercentile(calc_data, 2)
#     201     else:
# --> 202         vmin = np.nanmin(calc_data)
#     203 if vmax is None:
#     204     if robust:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:343, in nanmin(a, axis, out, keepdims, initial, where)
#     338     kwargs['where'] = where
#     340 if type(a) is np.ndarray and a.dtype != np.object_:
#     341     # Fast, but not safe for subclasses of ndarray, or object arrays,
#     342     # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 343     res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     344     if np.isnan(res).any():
#     345         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     346                       stacklevel=2)
#
# ValueError: zero-size array to reduction operation fmin which has no identity
