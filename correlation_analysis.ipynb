# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests

import warnings
warnings.filterwarnings('ignore')

# %%
era5_features = [
        # Temperature variables
        'temperature_2m',                       # Air temperature
        'temperature_2m_min',                   # Daily minimum air temperature
        'temperature_2m_max',                   # Daily maximum air temperature
        'soil_temperature_level_1',             # Topsoil temperature (0-7 cm)
        'soil_temperature_level_2',             # Soil temperature (7-28 cm)
        
        # Moisture variables
        'volumetric_soil_water_layer_1',        # Topsoil moisture content
        'volumetric_soil_water_layer_2',        # Soil moisture (7-28 cm)
        'volumetric_soil_water_layer_3',        # Soil moisture (28-100 cm)
        'total_precipitation_sum',              # Total rainfall and snow
        'dewpoint_temperature_2m',              # Air humidity indicator
        
        # Radiation and energy variables
        'surface_solar_radiation_downwards_sum', # Solar radiation at surface
        'surface_net_solar_radiation_sum',       # Net solar radiation at surface
        
        # Evaporation and water cycle
        'total_evaporation_sum',                 # Actual evaporation
        
        # Wind variables
        'u_component_of_wind_10m',               # East-west wind component
        'v_component_of_wind_10m'                # North-south wind component
    ]

openweather_features = [
        'temp',         # Current temperature (C or K depending on units)
        'feels_like',   # Perceived temperature considering humidity and wind (C or K)
        'temp_min',     # Minimum temperature at the moment (C or K)
        'temp_max',     # Maximum temperature at the moment (C or K)
        'pressure',     # Atmospheric pressure at sea level (hPa)
        'humidity',     # Humidity percentage (%)
        'wind_speed',   # Wind speed (meter/sec)
        'wind_deg',     # Wind direction in degrees (0–360)
        'rain_1h',      # Rain volume for the last 1 hour (mm)
        'rain_3h',      # Rain volume for the last 3 hours (mm)
        'clouds_all'    # Cloudiness percentage (%)
    ]

chirts_features = [
        'heat_index',
        'maximum_temperature',
        'minimum_temperature',
        'relative_humidity',
        'saturation_vapor_pressure',
        'vapor_pressure_deficit',
    ]

power_features = [
        'T2M',           # MERRA-2 Temperature at 2 Meters (C)
        'T2MDEW',        # MERRA-2 Dew/Frost Point at 2 Meters (C)
        'T2MWET',        # MERRA-2 Wet Bulb Temperature at 2 Meters (C)
        'TS',            # MERRA-2 Earth Skin Temperature (C)
        'T2M_RANGE',     # MERRA-2 Temperature at 2 Meters Range (C)
        'T2M_MAX',       # MERRA-2 Temperature at 2 Meters Maximum (C)
        'T2M_MIN',       # MERRA-2 Temperature at 2 Meters Minimum (C)
        'PS',            # MERRA-2 Surface Pressure (kPa)
        'WS2M',          # MERRA-2 Wind Speed at 2 Meters (m/s)
        'WS2M_MAX',      # MERRA-2 Wind Speed at 2 Meters Maximum (m/s)
        'WS2M_MIN',      # MERRA-2 Wind Speed at 2 Meters Minimum (m/s)
        'GWETTOP',       # MERRA-2 Surface Soil Wetness (1)
        'GWETROOT'      # MERRA-2 Root Zone Soil Wetness (1)
    ]

selected_features = era5_features

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# konfigurasi parameter
start_year = 2020
end_year = 2025
climate_dir = "climate_timeseries/cleaned/"
vegetation_dir = "pandanwangi_timeseries/"
viz_dir = "visualization/"
evi = True
kecamatan_names = ['warungkondang']

era5_datasets = ['era5_warungkondang.csv']
chirts_datasets = ['chirts_warungkondang.csv']
ow_datasets = ['OpenWeather_warungkondang.csv']
power_datasets = ['power_warungkondang.csv']

selected_dataset = era5_datasets

available_vegetation_datasets = ['warungkondang.csv']

selected_kec = kecamatan_names[0]

if evi:
    available_vegetation_datasets = ['evi_' + dataset for dataset in available_vegetation_datasets]

extract_statistics = ['mean', 'min', 'max', 'std']
statistic_corr = ['mean', 'min', 'max', 'std', 'smoothed_mean']

temporal_resolution = '5D'

# %%
# load seluruh data climate
def load_climate_data(climate_dir, datasets, kecamatan_names):
    climate_df = {}
    for i, dataset in enumerate(selected_dataset):
        try:
            curr = pd.read_csv(f"{climate_dir}/{dataset}")
            kec = kecamatan_names[min(i, len(kecamatan_names)-1)]
            climate_df[kec] = curr
        except Exception as e:
            print(f"File kecamatan {kec} tidak dapat dimuat: {e}")
    return climate_df

# load seluruh data vegetasi
def load_vegetation_data(vegetation_dir, datasets, kecamatan_names):
    vegetation_df = {}
    for i, dataset in enumerate(datasets):
        try:
            curr = pd.read_csv(f"{vegetation_dir}/{dataset}")
            kec = kecamatan_names[min(i, len(kecamatan_names)-1)]
            vegetation_df[kec] = curr
        except Exception as e:
            print(f"File vegetasi {kec} tidak dapat dimuat: {e}")
    return vegetation_df

# process data cuaca
def climate_df_processing(df):
    df['datetime'] = pd.to_datetime(df['datetime'], format='%Y-%m-%d')
    df.set_index('datetime', inplace=True)
    
    return df[(df.index.year >= start_year) & (df.index.year <= end_year)]

# process data vegetasi
def vegetation_preprocessing(df):
    df = df.iloc[:,2:]
    df = df[df.label == 'pandanwangi']
    df = df.set_index('cluster_id') 
    df = df.describe()
    df = df.T # transpose urutan waktu menjadi baris
    df = df[extract_statistics] # ambil fitur statistik yang diinginkan dari .describe()
    
    indexes = df.index
    new_indexes = []
    print(indexes)
    for i in indexes:
        date = pd.to_datetime(i, format='%Y%m%d')
        new_indexes.append(date)
    
    df['datetime'] = new_indexes
    df = df.set_index('datetime')
    df = df.asfreq(temporal_resolution, method='nearest') # resample data, dengan space temporal menjadi per 5 hari dengan metode nilai terdekat
    
    return df[(df.index.year >= start_year) & (df.index.year <= end_year)]

# function untuk mem-filter dataframe dengan metode savitzky-golay 
def smoothing_sg(df, window_length=16, polyorder=3):
    for col in ['mean', 'min', 'max']:
        filtered = savgol_filter(df[col], window_length=window_length, polyorder=polyorder)
        df[f'smoothed_{col}'] = filtered
    return df


# melakukan differencing pada data time series
def difference_df(df):
    return df.diff()
    
# mengecek stasioneritas pada data dengan Dicky-Fuller test dengan alpha 5%
def test_stationarity(df):
    results = {}
    for col in df.columns:
        adf_result = sm.tsa.stattools.adfuller(df[col].dropna())
        results[col] = {
            'ADF Statistic': adf_result[0],
            'p-value': adf_result[1],
            'Stationary': adf_result[1] < 0.05
        }
    return pd.DataFrame(results).T

# hitung korelasi dengan lag
def calculate_lagged_correlation(climate_df, vegetation_df, max_lag=30):
    vegetation_stats = statistic_corr
    
    lag_correlation = {
        'statistic': [],
        'climate_feature': [],
        'lag': [],
        'correlation': [],
        'p_value': []
    }
    
    for stat in vegetation_stats:
        if stat in vegetation_df.columns:
            veg_series = vegetation_df[stat]
            
            for feature in climate_df.columns:
                climate_series = climate_df[feature]
                
                intersecting_idx = veg_series.index.intersection(climate_series.index) # kedua dataset yang dibandingkan mempunyai index yang sama (time range yang sama)
                veg_adjusted = veg_series.loc[intersecting_idx]
                climate_adjusted = climate_series.loc[intersecting_idx]
                
                # hitung cross-correlation untuk lag 0 hingga 30 (pada time series)
                for lag in range(max_lag+1):
                    x = climate_adjusted.iloc[:-lag].values if lag != 0 else climate_adjusted.values
                    y = veg_adjusted.iloc[lag:].values if lag != 0 else veg_adjusted.values
                    
                    corr, p_value = stats.pearsonr(x, y)
                    
                    lag_correlation['statistic'].append(stat)
                    lag_correlation['climate_feature'].append(feature)
                    lag_correlation['lag'].append(lag)
                    lag_correlation['correlation'].append(corr)
                    lag_correlation['p_value'].append(p_value)
    
    return pd.DataFrame(lag_correlation)

# granger causality
def granger_causality_test(climate_df, vegetation_df, max_lag=10):
    
    results = {
        'climate_feature': [],
        'vegetation_stat': [],
        'max_lag': [],
        'min_p_value': [],
        'causality_direction': []
    }
    
    for climate_feature in climate_df.columns:
        for veg_stat in vegetation_df.columns:
            if veg_stat in statistic_corr:
                
                intersecting_idx = climate_df.index.intersection(vegetation_df.index)

                climate_series = climate_df[climate_feature].loc[intersecting_idx]
                veg_series = vegetation_df[veg_stat].loc[intersecting_idx]
                
                # data yang akan dilakukan granger test
                data = pd.DataFrame({
                    'climate': climate_series,
                    'vegetation': veg_series
                })
                
                # Test if climate Granger-causes vegetation
                try:
                    climate_to_veg = grangercausalitytests(data[['vegetation', 'climate']], 
                                                          maxlag=max_lag)

                    # print("grangertest:")
                    # print(climate_to_veg)

                    min_p_climate_to_veg = min([climate_to_veg[lag][0]['ssr_chi2test'][1] 
                                             for lag in range(1, max_lag+1)])
                    
                    # Determine causality direction
                    if min_p_climate_to_veg < 0.05:
                        direction = 'granger-causal'
                        min_p = min_p_climate_to_veg
                    else:
                        direction = 'none'
                        min_p = min(min_p_climate_to_veg, min_p_veg_to_climate)
                    
                    results['climate_feature'].append(climate_feature)
                    results['vegetation_stat'].append(veg_stat)
                    results['max_lag'].append(max_lag)
                    results['min_p_value'].append(min_p)
                    results['causality_direction'].append(direction)
                
                except Exception as e:
                    print(f"Error in Granger test: {e}")
    
    return pd.DataFrame(results)

# Visualize time series data
def plot_time_series(climate_df, vegetation_df, feature, stat):
    fig, ax1 = plt.subplots(figsize=(14, 6))
    
    # Plot climate data
    color = 'tab:blue'
    ax1.set_xlabel('Date')
    ax1.set_ylabel(feature, color=color)
    climate_series = climate_df[feature]
    ax1.plot(climate_series.index, climate_series.values, color=color, label=feature)
    ax1.tick_params(axis='y', labelcolor=color)
    
    # Create second y-axis for vegetation data
    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2.set_ylabel(f'Vegetation {stat}', color=color)
    veg_series = vegetation_df[stat]
    ax2.plot(veg_series.index, veg_series.values, color=color, label=f'Vegetation {stat}')
    ax2.tick_params(axis='y', labelcolor=color)
    
    # Add title and legend
    plt.title(f'Time Series: {feature} vs Vegetation {stat}')
    fig.tight_layout()
    fig.legend(loc="upper left", bbox_to_anchor=(0.1, 0.9))
    plt.savefig(f'{viz_dir}time_series_{feature}_{stat}.png')
    plt.close()

# Visualize lag correlation
def plot_lag_correlation(lag_corr_df, vegetation_stat, climate_feature):
    subset = lag_corr_df[(lag_corr_df['statistic'] == vegetation_stat) & 
                         (lag_corr_df['climate_feature'] == climate_feature)]
    
    plt.figure(figsize=(10, 5))
    plt.plot(subset['lag'], subset['correlation'], marker='o')
    plt.axhline(y=0, color='r', linestyle='-', alpha=0.3)
    
    # Add significance threshold lines (assuming p<0.05)
    significant = subset[subset['p_value'] < 0.05]
    plt.scatter(significant['lag'], significant['correlation'], color='red', 
                s=80, label='p < 0.05', zorder=3)
    
    plt.title(f'Lag Correlation: {climate_feature} vs Vegetation {vegetation_stat}')
    plt.xlabel('Lag (Negative: Climate leads, Positive: Vegetation leads)')
    plt.ylabel('Correlation Coefficient')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'{viz_dir}lag_correlation_{climate_feature}_{vegetation_stat}.png')
    plt.close()

# Visualize correlation heatmap
def plot_correlation_heatmap(lag_corr_df, lag=0):
    # Filter for specific lag
    lag_subset = lag_corr_df[lag_corr_df['lag'] == lag]
    
    # Prepare data for heatmap
    pivot_data = lag_subset.pivot_table(
        index='climate_feature', 
        columns='statistic', 
        values='correlation'
    )
    
    plt.figure(figsize=(12, 8))
    
    # Create heatmap
    sns.heatmap(pivot_data, annot=True, cmap='coolwarm', center=0, 
                vmin=-1, vmax=1, fmt='.2f')
    
    plt.title(f'Correlation Heatmap (Lag = {lag})')
    plt.tight_layout()
    plt.savefig(f'{viz_dir}correlation_heatmap_lag_{lag}.png')
    plt.close()
    
    # Also create p-value heatmap
    p_value_pivot = lag_subset.pivot_table(
        index='climate_feature', 
        columns='statistic', 
        values='p_value'
    )
    
    plt.figure(figsize=(12, 8))
    sns.heatmap(p_value_pivot < 0.05, annot=p_value_pivot, cmap='viridis', 
                fmt='.3f', cbar_kws={'label': 'p-value'})
    
    plt.title(f'P-values Heatmap (Lag = {lag})')
    plt.tight_layout()
    plt.savefig(f'{viz_dir}pvalue_heatmap_lag_{lag}.png')
    plt.close()

# %%
def main():
    climate_df = load_climate_data(climate_dir, era5_datasets, kecamatan_names)
    vegetation_df = load_vegetation_data(vegetation_dir, available_vegetation_datasets, kecamatan_names)
    
    preprocessed_climate = {}
    preprocessed_vegetation = {}

    # lakukan preprocess pada setiap kecamatan
    for kec in kecamatan_names:
        preprocessed_climate[kec] = climate_df_processing(climate_df[kec])
        preprocessed_vegetation[kec] = vegetation_preprocessing(vegetation_df[kec])
        preprocessed_vegetation[kec] = smoothing_sg(preprocessed_vegetation[kec])

    # print(preprocessed_vegetation['warungkondang'].value_counts())
    
    # uji stasioneritas
    for kec in kecamatan_names:
        print(f"\nStationarity Test for Climate Data ({kec}):")
        climate_stationarity = test_stationarity(preprocessed_climate[kec])
        print(climate_stationarity)
        
        print(f"\nStationarity Test for Vegetation Data ({kec}):")
        vegetation_stationarity = test_stationarity(preprocessed_vegetation[kec])
        print(vegetation_stationarity)
    
    differenced_climate = {}
    differenced_vegetation = {}
    
    for kec in kecamatan_names:
        climate_stationary = test_stationarity(preprocessed_climate[kec])
        veg_stationary = test_stationarity(preprocessed_vegetation[kec])

        differenced_climate[kec] = difference_df(preprocessed_climate[kec])
        print(f"Applied differencing to climate data for {kec}")
        differenced_vegetation[kec] = difference_df(preprocessed_vegetation[kec])
        print(f"Applied differencing to vegetation data for {kec}")
    
    # adjust data agar mempunyai time series yang sama
    adjusted_data = {}
    for kec in kecamatan_names:
        intersecting_idx = differenced_climate[kec].index.intersection(differenced_vegetation[kec].index)
        adjusted_data[kec] = {
            'climate': differenced_climate[kec].loc[intersecting_idx].interpolate().bfill().ffill(),
            'vegetation': differenced_vegetation[kec].loc[intersecting_idx].interpolate().bfill().ffill()
        }
        
    # print("adjusted_data", adjusted_data)
    # hitung korelasi dengan faktor lag hingga 30
    results = {}
    for kec in kecamatan_names:
        print(f"\nLagged correlations for {kec}...")
        lag_corr_df = calculate_lagged_correlation(
            adjusted_data[kec]['climate'], 
            adjusted_data[kec]['vegetation'], 
            max_lag=30
        )
        results[kec] = lag_corr_df

    print("hasil result:")
    print(results)
    print(selected_kec)
    # cari korelasi terkuat
    for kec in kecamatan_names:
        lag_corr = results[kec]
        # ambil korelasi signifikan dan terkuat
        significant = lag_corr[lag_corr['p_value'] < 0.05]
        strongest = significant.loc[significant['correlation'].abs().sort_values(ascending=False).index]
        
        print(f"\nTop 10 strongest correlations for {kec}:")
        print(strongest.head(15))
    
    # Granger causality test
    for kec in kecamatan_names:
        print(f"\nGranger causality test for {kec}...")
        granger_results = granger_causality_test(
            adjusted_data[kec]['climate'],
            adjusted_data[kec]['vegetation']
        )
        
        # Filter for significant causal relationships
        significant_causality = granger_results[granger_results['min_p_value'] < 0.05]
        
        print(f"\nSignificant causal relationships for {kec}:")
        print(significant_causality)
    
    # 1. Time series plots for top correlations
    if len(significant) > 0:
        top_correlation = strongest.iloc[0]
        feature = top_correlation['climate_feature']
        stat = top_correlation['statistic']

        plot_time_series(
            adjusted_data[selected_kec]['climate'],
            adjusted_data[selected_kec]['vegetation'],
            feature, stat
        )
    
    # 2. Lag correlation plots
    for feature in chirts_features[:3]:  # Plot first 3 features for example
        for stat in ['mean', 'smoothed_mean']:
            plot_lag_correlation(results[selected_kec], stat, feature)
    
    # 3. Correlation heatmaps at different lags
    for lag in [-10, -5, 0, 5, 10]:
        plot_correlation_heatmap(results[selected_kec], lag)
    
    print("\nAnalysis complete! Visualization files have been saved.")

if __name__ == "__main__":
    main()
# Out:
# Index(['19880414', '19880601', '19880617', '19880820', '19890706', '19900420',
#        '19900607', '19900725', '19900810', '19910914',
#        ...
#        '20241109', '20250418', '20250420', '20250423', '20250428', '20250503',
#        '20250505', '20250506', '20250508', '20250513'],
#       dtype='object', length=655)
#
# Stationarity Test for Climate Data (warungkondang):
#                                       ADF Statistic   p-value Stationary
# temperature_2m                             -4.92619  0.000031       True
# temperature_2m_min                        -4.226481  0.000594       True
# temperature_2m_max                        -4.818168   0.00005       True
# soil_temperature_level_1                  -4.012183  0.001348       True
# soil_temperature_level_2                  -3.425184   0.01013       True
# volumetric_soil_water_layer_1             -4.945737  0.000028       True
# volumetric_soil_water_layer_2             -4.202466  0.000653       True
# volumetric_soil_water_layer_3             -3.762532  0.003315       True
# total_precipitation_sum                    -7.75481       0.0       True
# dewpoint_temperature_2m                   -3.599118  0.005778       True
# surface_solar_radiation_downwards_sum     -7.265545       0.0       True
# surface_net_solar_radiation_sum           -7.306667       0.0       True
# total_evaporation_sum                     -7.666104       0.0       True
# u_component_of_wind_10m                   -4.792464  0.000056       True
# v_component_of_wind_10m                  -12.773807       0.0       True
# temperature_range                         -3.649748  0.004878       True
#
# Stationarity Test for Vegetation Data (warungkondang):
#               ADF Statistic   p-value Stationary
# mean              -5.839339       0.0       True
# min              -18.428499       0.0       True
# max               -4.093133  0.000994       True
# std               -4.326626  0.000399       True
# smoothed_mean     -3.088967  0.027381       True
# smoothed_min      -4.027092  0.001275       True
# smoothed_max      -3.784563  0.003069       True
# Applied differencing to climate data for warungkondang
# Applied differencing to vegetation data for warungkondang
#
# Lagged correlations for warungkondang...
# hasil result:
# {'warungkondang':           statistic    climate_feature  lag  correlation   p_value
# 0              mean     temperature_2m    0     0.037400  0.476266
# 1              mean     temperature_2m    1     0.034325  0.513878
# 2              mean     temperature_2m    2    -0.025240  0.631718
# 3              mean     temperature_2m    3    -0.018045  0.732220
# 4              mean     temperature_2m    4    -0.007739  0.883496
# ...             ...                ...  ...          ...       ...
# 2475  smoothed_mean  temperature_range   26     0.032721  0.548246
# 2476  smoothed_mean  temperature_range   27     0.015033  0.783027
# 2477  smoothed_mean  temperature_range   28     0.042710  0.434514
# 2478  smoothed_mean  temperature_range   29    -0.027727  0.612539
# 2479  smoothed_mean  temperature_range   30    -0.064513  0.238956
#
# [2480 rows x 5 columns]}
# warungkondang
#
# Top 10 strongest correlations for warungkondang:
#           statistic                        climate_feature  lag  correlation  \
# 396            mean                  total_evaporation_sum   24    -0.211805
# 334            mean  surface_solar_radiation_downwards_sum   24     0.179761
# 365            mean        surface_net_solar_radiation_sum   24     0.179174
# 2245  smoothed_mean                total_precipitation_sum   13     0.172807
# 1204            max          volumetric_soil_water_layer_2   26     0.170782
# 2161  smoothed_mean          volumetric_soil_water_layer_1   22    -0.164786
# 2221  smoothed_mean          volumetric_soil_water_layer_3   20     0.164720
# 174            mean          volumetric_soil_water_layer_1   19    -0.164255
# 489            mean                      temperature_range   24     0.159597
# 2285  smoothed_mean                dewpoint_temperature_2m   22    -0.158269
# 2223  smoothed_mean          volumetric_soil_water_layer_3   22     0.156850
# 123            mean               soil_temperature_level_1   30    -0.156594
# 1700            std          volumetric_soil_water_layer_2   26     0.154397
# 2222  smoothed_mean          volumetric_soil_water_layer_3   21     0.153717
# 924             min                u_component_of_wind_10m   25    -0.153453
#
#        p_value
# 396   0.000081
# 334   0.000854
# 365   0.000889
# 2245  0.001133
# 1204  0.001599
# 2161  0.002201
# 2221  0.002145
# 174   0.002176
# 489   0.003124
# 2285  0.003292
# 2223  0.003587
# 123   0.004064
# 1700  0.004381
# 2222  0.004268
# 924   0.004569
#
# Granger causality test for warungkondang...
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6419  , p=0.4236  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.6472  , p=0.4211  , df=1
# likelihood ratio test: chi2=0.6466  , p=0.4213  , df=1
# parameter F test:         F=0.6419  , p=0.4236  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3975  , p=0.6723  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.8061  , p=0.6683  , df=2
# likelihood ratio test: chi2=0.8052  , p=0.6686  , df=2
# parameter F test:         F=0.3975  , p=0.6723  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2761  , p=0.8427  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=0.8445  , p=0.8388  , df=3
# likelihood ratio test: chi2=0.8435  , p=0.8390  , df=3
# parameter F test:         F=0.2761  , p=0.8427  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2103  , p=0.9326  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=0.8629  , p=0.9298  , df=4
# likelihood ratio test: chi2=0.8618  , p=0.9300  , df=4
# parameter F test:         F=0.2103  , p=0.9326  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6857  , p=0.6346  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.5366  , p=0.6179  , df=5
# likelihood ratio test: chi2=3.5193  , p=0.6205  , df=5
# parameter F test:         F=0.6857  , p=0.6346  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2801  , p=0.2657  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=7.9690  , p=0.2404  , df=6
# likelihood ratio test: chi2=7.8819  , p=0.2469  , df=6
# parameter F test:         F=1.2801  , p=0.2657  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1150  , p=0.3530  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=8.1462  , p=0.3199  , df=7
# likelihood ratio test: chi2=8.0549  , p=0.3278  , df=7
# parameter F test:         F=1.1150  , p=0.3530  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0166  , p=0.4230  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=8.5393  , p=0.3826  , df=8
# likelihood ratio test: chi2=8.4388  , p=0.3918  , df=8
# parameter F test:         F=1.0166  , p=0.4230  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9383  , p=0.4917  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=8.9212  , p=0.4446  , df=9
# likelihood ratio test: chi2=8.8113  , p=0.4549  , df=9
# parameter F test:         F=0.9383  , p=0.4917  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8122  , p=0.6171  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=8.6326  , p=0.5673  , df=10
# likelihood ratio test: chi2=8.5293  , p=0.5773  , df=10
# parameter F test:         F=0.8122  , p=0.6171  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2516  , p=0.2640  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.2620  , p=0.2613  , df=1
# likelihood ratio test: chi2=1.2598  , p=0.2617  , df=1
# parameter F test:         F=1.2516  , p=0.2640  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4747  , p=0.2302  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.9907  , p=0.2242  , df=2
# likelihood ratio test: chi2=2.9784  , p=0.2255  , df=2
# parameter F test:         F=1.4747  , p=0.2302  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4560  , p=0.2263  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=4.4541  , p=0.2164  , df=3
# likelihood ratio test: chi2=4.4269  , p=0.2189  , df=3
# parameter F test:         F=1.4560  , p=0.2263  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1043  , p=0.3543  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.5300  , p=0.3390  , df=4
# likelihood ratio test: chi2=4.5018  , p=0.3423  , df=4
# parameter F test:         F=1.1043  , p=0.3543  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2783  , p=0.2727  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=6.5927  , p=0.2527  , df=5
# likelihood ratio test: chi2=6.5331  , p=0.2577  , df=5
# parameter F test:         F=1.2783  , p=0.2727  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9462  , p=0.4619  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=5.8905  , p=0.4356  , df=6
# likelihood ratio test: chi2=5.8427  , p=0.4410  , df=6
# parameter F test:         F=0.9462  , p=0.4619  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9271  , p=0.4855  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=6.7732  , p=0.4529  , df=7
# likelihood ratio test: chi2=6.7099  , p=0.4597  , df=7
# parameter F test:         F=0.9271  , p=0.4855  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9169  , p=0.5025  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=7.7016  , p=0.4631  , df=8
# likelihood ratio test: chi2=7.6197  , p=0.4715  , df=8
# parameter F test:         F=0.9169  , p=0.5025  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8423  , p=0.5776  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=8.0082  , p=0.5333  , df=9
# likelihood ratio test: chi2=7.9194  , p=0.5423  , df=9
# parameter F test:         F=0.8423  , p=0.5776  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8126  , p=0.6167  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=8.6373  , p=0.5668  , df=10
# likelihood ratio test: chi2=8.5339  , p=0.5768  , df=10
# parameter F test:         F=0.8126  , p=0.6167  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8172  , p=0.1785  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.8323  , p=0.1759  , df=1
# likelihood ratio test: chi2=1.8277  , p=0.1764  , df=1
# parameter F test:         F=1.8172  , p=0.1785  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2069  , p=0.3003  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.4476  , p=0.2941  , df=2
# likelihood ratio test: chi2=2.4394  , p=0.2953  , df=2
# parameter F test:         F=1.2069  , p=0.3003  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8120  , p=0.4879  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.4840  , p=0.4782  , df=3
# likelihood ratio test: chi2=2.4755  , p=0.4797  , df=3
# parameter F test:         F=0.8120  , p=0.4879  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9077  , p=0.4595  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=3.7236  , p=0.4447  , df=4
# likelihood ratio test: chi2=3.7045  , p=0.4475  , df=4
# parameter F test:         F=0.9077  , p=0.4595  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8647  , p=0.5050  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.4597  , p=0.4853  , df=5
# likelihood ratio test: chi2=4.4323  , p=0.4890  , df=5
# parameter F test:         F=0.8647  , p=0.5050  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0320  , p=0.4041  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=6.4245  , p=0.3774  , df=6
# likelihood ratio test: chi2=6.3677  , p=0.3833  , df=6
# parameter F test:         F=1.0320  , p=0.4041  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0384  , p=0.4038  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.5865  , p=0.3705  , df=7
# likelihood ratio test: chi2=7.5072  , p=0.3780  , df=7
# parameter F test:         F=1.0384  , p=0.4038  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8910  , p=0.5242  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=7.4840  , p=0.4854  , df=8
# likelihood ratio test: chi2=7.4066  , p=0.4935  , df=8
# parameter F test:         F=0.8910  , p=0.5242  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8011  , p=0.6155  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=7.6168  , p=0.5732  , df=9
# likelihood ratio test: chi2=7.5364  , p=0.5814  , df=9
# parameter F test:         F=0.8011  , p=0.6155  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7188  , p=0.7068  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=7.6398  , p=0.6640  , df=10
# likelihood ratio test: chi2=7.5587  , p=0.6719  , df=10
# parameter F test:         F=0.7188  , p=0.7068  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9984  , p=0.3184  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.0067  , p=0.3157  , df=1
# likelihood ratio test: chi2=1.0053  , p=0.3160  , df=1
# parameter F test:         F=0.9984  , p=0.3184  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1607  , p=0.3144  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.3538  , p=0.3082  , df=2
# likelihood ratio test: chi2=2.3462  , p=0.3094  , df=2
# parameter F test:         F=1.1607  , p=0.3144  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7732  , p=0.5096  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.3654  , p=0.5001  , df=3
# likelihood ratio test: chi2=2.3577  , p=0.5016  , df=3
# parameter F test:         F=0.7732  , p=0.5096  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8166  , p=0.5152  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=3.3498  , p=0.5011  , df=4
# likelihood ratio test: chi2=3.3344  , p=0.5035  , df=4
# parameter F test:         F=0.8166  , p=0.5152  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6779  , p=0.6405  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.4962  , p=0.6240  , df=5
# likelihood ratio test: chi2=3.4793  , p=0.6265  , df=5
# parameter F test:         F=0.6779  , p=0.6405  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9777  , p=0.4401  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=6.0866  , p=0.4136  , df=6
# likelihood ratio test: chi2=6.0355  , p=0.4192  , df=6
# parameter F test:         F=0.9777  , p=0.4401  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0427  , p=0.4008  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.6185  , p=0.3674  , df=7
# likelihood ratio test: chi2=7.5385  , p=0.3750  , df=7
# parameter F test:         F=1.0427  , p=0.4008  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8918  , p=0.5234  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=7.4915  , p=0.4846  , df=8
# likelihood ratio test: chi2=7.4140  , p=0.4927  , df=8
# parameter F test:         F=0.8918  , p=0.5234  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7945  , p=0.6216  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=7.5536  , p=0.5797  , df=9
# likelihood ratio test: chi2=7.4746  , p=0.5878  , df=9
# parameter F test:         F=0.7945  , p=0.6216  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7237  , p=0.7021  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=7.6925  , p=0.6588  , df=10
# likelihood ratio test: chi2=7.6104  , p=0.6668  , df=10
# parameter F test:         F=0.7237  , p=0.7021  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5627  , p=0.4537  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.5674  , p=0.4513  , df=1
# likelihood ratio test: chi2=0.5670  , p=0.4515  , df=1
# parameter F test:         F=0.5627  , p=0.4537  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8697  , p=0.1557  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=3.7916  , p=0.1502  , df=2
# likelihood ratio test: chi2=3.7719  , p=0.1517  , df=2
# parameter F test:         F=1.8697  , p=0.1557  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9463  , p=0.4183  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.8950  , p=0.4081  , df=3
# likelihood ratio test: chi2=2.8834  , p=0.4099  , df=3
# parameter F test:         F=0.9463  , p=0.4183  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6319  , p=0.6401  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.5921  , p=0.6282  , df=4
# likelihood ratio test: chi2=2.5829  , p=0.6299  , df=4
# parameter F test:         F=0.6319  , p=0.6401  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6552  , p=0.6577  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.3791  , p=0.6418  , df=5
# likelihood ratio test: chi2=3.3634  , p=0.6442  , df=5
# parameter F test:         F=0.6552  , p=0.6577  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7950  , p=0.0992  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=11.1744 , p=0.0831  , df=6
# likelihood ratio test: chi2=11.0040 , p=0.0883  , df=6
# parameter F test:         F=1.7950  , p=0.0992  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4796  , p=0.1734  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=10.8102 , p=0.1471  , df=7
# likelihood ratio test: chi2=10.6502 , p=0.1546  , df=7
# parameter F test:         F=1.4796  , p=0.1734  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2337  , p=0.2783  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=10.3631 , p=0.2405  , df=8
# likelihood ratio test: chi2=10.2155 , p=0.2502  , df=8
# parameter F test:         F=1.2337  , p=0.2783  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1509  , p=0.3262  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=10.9420 , p=0.2797  , df=9
# likelihood ratio test: chi2=10.7772 , p=0.2913  , df=9
# parameter F test:         F=1.1509  , p=0.3262  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2800  , p=0.2403  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=13.6043 , p=0.1918  , df=10
# likelihood ratio test: chi2=13.3501 , p=0.2048  , df=10
# parameter F test:         F=1.2800  , p=0.2403  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5482  , p=0.2142  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=1.5611  , p=0.2115  , df=1
# likelihood ratio test: chi2=1.5578  , p=0.2120  , df=1
# parameter F test:         F=1.5482  , p=0.2142  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1934  , p=0.3044  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.4202  , p=0.2982  , df=2
# likelihood ratio test: chi2=2.4122  , p=0.2994  , df=2
# parameter F test:         F=1.1934  , p=0.3044  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9215  , p=0.4305  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.8191  , p=0.4204  , df=3
# likelihood ratio test: chi2=2.8082  , p=0.4222  , df=3
# parameter F test:         F=0.9215  , p=0.4305  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7091  , p=0.5862  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.9088  , p=0.5732  , df=4
# likelihood ratio test: chi2=2.8972  , p=0.5752  , df=4
# parameter F test:         F=0.7091  , p=0.5862  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8005  , p=0.5499  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.1286  , p=0.5310  , df=5
# likelihood ratio test: chi2=4.1051  , p=0.5344  , df=5
# parameter F test:         F=0.8005  , p=0.5499  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8353  , p=0.5432  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=5.2004  , p=0.5184  , df=6
# likelihood ratio test: chi2=5.1631  , p=0.5231  , df=6
# parameter F test:         F=0.8353  , p=0.5432  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7166  , p=0.6580  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=5.2357  , p=0.6312  , df=7
# likelihood ratio test: chi2=5.1978  , p=0.6358  , df=7
# parameter F test:         F=0.7166  , p=0.6580  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6263  , p=0.7557  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=5.2609  , p=0.7294  , df=8
# likelihood ratio test: chi2=5.2225  , p=0.7335  , df=8
# parameter F test:         F=0.6263  , p=0.7557  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0578  , p=0.3938  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=10.0567 , p=0.3459  , df=9
# likelihood ratio test: chi2=9.9173  , p=0.3572  , df=9
# parameter F test:         F=1.0578  , p=0.3938  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9963  , p=0.4463  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=10.5891 , p=0.3904  , df=10
# likelihood ratio test: chi2=10.4342 , p=0.4033  , df=10
# parameter F test:         F=0.9963  , p=0.4463  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.8006  , p=0.0951  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=2.8239  , p=0.0929  , df=1
# likelihood ratio test: chi2=2.8130  , p=0.0935  , df=1
# parameter F test:         F=2.8006  , p=0.0951  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8219  , p=0.4404  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.6668  , p=0.4346  , df=2
# likelihood ratio test: chi2=1.6630  , p=0.4354  , df=2
# parameter F test:         F=0.8219  , p=0.4404  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9311  , p=0.4258  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.8482  , p=0.4156  , df=3
# likelihood ratio test: chi2=2.8371  , p=0.4174  , df=3
# parameter F test:         F=0.9311  , p=0.4258  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2611  , p=0.2850  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=5.1734  , p=0.2700  , df=4
# likelihood ratio test: chi2=5.1367  , p=0.2736  , df=4
# parameter F test:         F=1.2611  , p=0.2850  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0807  , p=0.3707  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=5.5739  , p=0.3499  , df=5
# likelihood ratio test: chi2=5.5312  , p=0.3545  , df=5
# parameter F test:         F=1.0807  , p=0.3707  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0304  , p=0.4051  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=6.4149  , p=0.3783  , df=6
# likelihood ratio test: chi2=6.3583  , p=0.3843  , df=6
# parameter F test:         F=1.0304  , p=0.4051  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0272  , p=0.4116  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.5047  , p=0.3783  , df=7
# likelihood ratio test: chi2=7.4271  , p=0.3858  , df=7
# parameter F test:         F=1.0272  , p=0.4116  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2799  , p=0.2529  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=10.7508 , p=0.2162  , df=8
# likelihood ratio test: chi2=10.5921 , p=0.2259  , df=8
# parameter F test:         F=1.2799  , p=0.2529  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1625  , p=0.3183  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=11.0525 , p=0.2721  , df=9
# likelihood ratio test: chi2=10.8844 , p=0.2837  , df=9
# parameter F test:         F=1.1625  , p=0.3183  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2571  , p=0.2538  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=13.3617 , p=0.2041  , df=10
# likelihood ratio test: chi2=13.1164 , p=0.2172  , df=10
# parameter F test:         F=1.2571  , p=0.2538  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6344  , p=0.4263  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.6397  , p=0.4238  , df=1
# likelihood ratio test: chi2=0.6391  , p=0.4240  , df=1
# parameter F test:         F=0.6344  , p=0.4263  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9584  , p=0.3845  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.9435  , p=0.3784  , df=2
# likelihood ratio test: chi2=1.9384  , p=0.3794  , df=2
# parameter F test:         F=0.9584  , p=0.3845  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7301  , p=0.5346  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=2.2335  , p=0.5254  , df=3
# likelihood ratio test: chi2=2.2266  , p=0.5267  , df=3
# parameter F test:         F=0.7301  , p=0.5346  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6260  , p=0.6443  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.5679  , p=0.6325  , df=4
# likelihood ratio test: chi2=2.5588  , p=0.6341  , df=4
# parameter F test:         F=0.6260  , p=0.6443  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5684  , p=0.7242  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.9315  , p=0.7105  , df=5
# likelihood ratio test: chi2=2.9197  , p=0.7124  , df=5
# parameter F test:         F=0.5684  , p=0.7242  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5883  , p=0.7397  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=3.6627  , p=0.7222  , df=6
# likelihood ratio test: chi2=3.6441  , p=0.7247  , df=6
# parameter F test:         F=0.5883  , p=0.7397  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5783  , p=0.7736  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=4.2251  , p=0.7535  , df=7
# likelihood ratio test: chi2=4.2004  , p=0.7564  , df=7
# parameter F test:         F=0.5783  , p=0.7736  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5785  , p=0.7956  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=4.8591  , p=0.7725  , df=8
# likelihood ratio test: chi2=4.8263  , p=0.7760  , df=8
# parameter F test:         F=0.5785  , p=0.7956  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5665  , p=0.8244  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=5.3862  , p=0.7994  , df=9
# likelihood ratio test: chi2=5.3458  , p=0.8032  , df=9
# parameter F test:         F=0.5665  , p=0.8244  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5811  , p=0.8294  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=6.1763  , p=0.8002  , df=10
# likelihood ratio test: chi2=6.1232  , p=0.8048  , df=10
# parameter F test:         F=0.5811  , p=0.8294  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2898  , p=0.5907  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.2922  , p=0.5888  , df=1
# likelihood ratio test: chi2=0.2920  , p=0.5889  , df=1
# parameter F test:         F=0.2898  , p=0.5907  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9041  , p=0.4058  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.8334  , p=0.3998  , df=2
# likelihood ratio test: chi2=1.8288  , p=0.4008  , df=2
# parameter F test:         F=0.9041  , p=0.4058  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6237  , p=0.6001  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.9079  , p=0.5917  , df=3
# likelihood ratio test: chi2=1.9029  , p=0.5928  , df=3
# parameter F test:         F=0.6237  , p=0.6001  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5650  , p=0.6882  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.3176  , p=0.6776  , df=4
# likelihood ratio test: chi2=2.3102  , p=0.6789  , df=4
# parameter F test:         F=0.5650  , p=0.6882  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5770  , p=0.7176  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.9761  , p=0.7037  , df=5
# likelihood ratio test: chi2=2.9639  , p=0.7056  , df=5
# parameter F test:         F=0.5770  , p=0.7176  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6895  , p=0.6582  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=4.2925  , p=0.6372  , df=6
# likelihood ratio test: chi2=4.2670  , p=0.6406  , df=6
# parameter F test:         F=0.6895  , p=0.6582  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6337  , p=0.7280  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=4.6300  , p=0.7050  , df=7
# likelihood ratio test: chi2=4.6004  , p=0.7086  , df=7
# parameter F test:         F=0.6337  , p=0.7280  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7007  , p=0.6910  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=5.8858  , p=0.6600  , df=8
# likelihood ratio test: chi2=5.8378  , p=0.6654  , df=8
# parameter F test:         F=0.7007  , p=0.6910  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7413  , p=0.6709  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=7.0480  , p=0.6321  , df=9
# likelihood ratio test: chi2=6.9791  , p=0.6393  , df=9
# parameter F test:         F=0.7413  , p=0.6709  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6964  , p=0.7279  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=7.4016  , p=0.6871  , df=10
# likelihood ratio test: chi2=7.3255  , p=0.6944  , df=10
# parameter F test:         F=0.6964  , p=0.7279  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8402  , p=0.3600  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.8472  , p=0.3574  , df=1
# likelihood ratio test: chi2=0.8462  , p=0.3576  , df=1
# parameter F test:         F=0.8402  , p=0.3600  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9918  , p=0.3719  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.0114  , p=0.3658  , df=2
# likelihood ratio test: chi2=2.0058  , p=0.3668  , df=2
# parameter F test:         F=0.9918  , p=0.3719  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1390  , p=0.3332  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.4843  , p=0.3228  , df=3
# likelihood ratio test: chi2=3.4677  , p=0.3250  , df=3
# parameter F test:         F=1.1390  , p=0.3332  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0016  , p=0.4067  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.1089  , p=0.3915  , df=4
# likelihood ratio test: chi2=4.0857  , p=0.3945  , df=4
# parameter F test:         F=1.0016  , p=0.4067  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8270  , p=0.5311  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.2654  , p=0.5119  , df=5
# likelihood ratio test: chi2=4.2403  , p=0.5154  , df=5
# parameter F test:         F=0.8270  , p=0.5311  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1137  , p=0.3537  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=6.9335  , p=0.3270  , df=6
# likelihood ratio test: chi2=6.8674  , p=0.3333  , df=6
# parameter F test:         F=1.1137  , p=0.3537  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0026  , p=0.4291  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.3249  , p=0.3959  , df=7
# likelihood ratio test: chi2=7.2509  , p=0.4032  , df=7
# parameter F test:         F=1.0026  , p=0.4291  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0454  , p=0.4015  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=8.7817  , p=0.3610  , df=8
# likelihood ratio test: chi2=8.6754  , p=0.3704  , df=8
# parameter F test:         F=1.0454  , p=0.4015  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2485  , p=0.2644  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=11.8704 , p=0.2207  , df=9
# likelihood ratio test: chi2=11.6768 , p=0.2321  , df=9
# parameter F test:         F=1.2485  , p=0.2644  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1522  , p=0.3226  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=12.2468 , p=0.2689  , df=10
# likelihood ratio test: chi2=12.0403 , p=0.2824  , df=10
# parameter F test:         F=1.1522  , p=0.3226  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6105  , p=0.4351  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.6156  , p=0.4327  , df=1
# likelihood ratio test: chi2=0.6151  , p=0.4329  , df=1
# parameter F test:         F=0.6105  , p=0.4351  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6064  , p=0.5459  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.2298  , p=0.5407  , df=2
# likelihood ratio test: chi2=1.2277  , p=0.5413  , df=2
# parameter F test:         F=0.6064  , p=0.5459  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3979  , p=0.7546  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.2173  , p=0.7489  , df=3
# likelihood ratio test: chi2=1.2152  , p=0.7494  , df=3
# parameter F test:         F=0.3979  , p=0.7546  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2818  , p=0.8897  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=1.1561  , p=0.8853  , df=4
# likelihood ratio test: chi2=1.1542  , p=0.8856  , df=4
# parameter F test:         F=0.2818  , p=0.8897  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3502  , p=0.2427  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=6.9638  , p=0.2233  , df=5
# likelihood ratio test: chi2=6.8973  , p=0.2284  , df=5
# parameter F test:         F=1.3502  , p=0.2427  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8084  , p=0.0966  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=11.2579 , p=0.0807  , df=6
# likelihood ratio test: chi2=11.0850 , p=0.0858  , df=6
# parameter F test:         F=1.8084  , p=0.0966  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5471  , p=0.1504  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=11.3031 , p=0.1259  , df=7
# likelihood ratio test: chi2=11.1284 , p=0.1331  , df=7
# parameter F test:         F=1.5471  , p=0.1504  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3685  , p=0.2092  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=11.4952 , p=0.1752  , df=8
# likelihood ratio test: chi2=11.3140 , p=0.1845  , df=8
# parameter F test:         F=1.3685  , p=0.2092  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2614  , p=0.2569  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=11.9927 , p=0.2137  , df=9
# likelihood ratio test: chi2=11.7951 , p=0.2251  , df=9
# parameter F test:         F=1.2614  , p=0.2569  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0747  , p=0.3811  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=11.4223 , p=0.3256  , df=10
# likelihood ratio test: chi2=11.2424 , p=0.3389  , df=10
# parameter F test:         F=1.0747  , p=0.3811  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1561  , p=0.6930  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.1574  , p=0.6915  , df=1
# likelihood ratio test: chi2=0.1574  , p=0.6916  , df=1
# parameter F test:         F=0.1561  , p=0.6930  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1475  , p=0.8629  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.2990  , p=0.8611  , df=2
# likelihood ratio test: chi2=0.2989  , p=0.8612  , df=2
# parameter F test:         F=0.1475  , p=0.8629  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0587  , p=0.9813  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=0.1797  , p=0.9808  , df=3
# likelihood ratio test: chi2=0.1796  , p=0.9808  , df=3
# parameter F test:         F=0.0587  , p=0.9813  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0416  , p=0.9967  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=0.1707  , p=0.9966  , df=4
# likelihood ratio test: chi2=0.1707  , p=0.9966  , df=4
# parameter F test:         F=0.0416  , p=0.9967  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2588  , p=0.9352  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=1.3348  , p=0.9313  , df=5
# likelihood ratio test: chi2=1.3324  , p=0.9316  , df=5
# parameter F test:         F=0.2588  , p=0.9352  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2124  , p=0.9728  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=1.3222  , p=0.9704  , df=6
# likelihood ratio test: chi2=1.3198  , p=0.9706  , df=6
# parameter F test:         F=0.2124  , p=0.9728  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4033  , p=0.9001  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=2.9465  , p=0.8899  , df=7
# likelihood ratio test: chi2=2.9345  , p=0.8910  , df=7
# parameter F test:         F=0.4033  , p=0.9001  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3777  , p=0.9322  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=3.1724  , p=0.9231  , df=8
# likelihood ratio test: chi2=3.1583  , p=0.9240  , df=8
# parameter F test:         F=0.3777  , p=0.9322  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3591  , p=0.9536  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=3.4139  , p=0.9456  , df=9
# likelihood ratio test: chi2=3.3977  , p=0.9464  , df=9
# parameter F test:         F=0.3591  , p=0.9536  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.3557  , p=0.9643  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=3.7811  , p=0.9567  , df=10
# likelihood ratio test: chi2=3.7611  , p=0.9575  , df=10
# parameter F test:         F=0.3557  , p=0.9643  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3073  , p=0.5797  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.3098  , p=0.5778  , df=1
# likelihood ratio test: chi2=0.3097  , p=0.5779  , df=1
# parameter F test:         F=0.3073  , p=0.5797  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5836  , p=0.5584  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.1836  , p=0.5533  , df=2
# likelihood ratio test: chi2=1.1817  , p=0.5539  , df=2
# parameter F test:         F=0.5836  , p=0.5584  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0141  , p=0.3865  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.1021  , p=0.3761  , df=3
# likelihood ratio test: chi2=3.0889  , p=0.3781  , df=3
# parameter F test:         F=1.0141  , p=0.3865  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1741  , p=0.3219  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.8163  , p=0.3067  , df=4
# likelihood ratio test: chi2=4.7845  , p=0.3101  , df=4
# parameter F test:         F=1.1741  , p=0.3219  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1306  , p=0.3437  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=5.8311  , p=0.3230  , df=5
# likelihood ratio test: chi2=5.7843  , p=0.3278  , df=5
# parameter F test:         F=1.1306  , p=0.3437  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2175  , p=0.2966  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=7.5793  , p=0.2706  , df=6
# likelihood ratio test: chi2=7.5004  , p=0.2770  , df=6
# parameter F test:         F=1.2175  , p=0.2966  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2486  , p=0.2754  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=9.1224  , p=0.2440  , df=7
# likelihood ratio test: chi2=9.0081  , p=0.2521  , df=7
# parameter F test:         F=1.2486  , p=0.2754  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0885  , p=0.3706  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=9.1431  , p=0.3304  , df=8
# likelihood ratio test: chi2=9.0280  , p=0.3399  , df=8
# parameter F test:         F=1.0885  , p=0.3706  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0167  , p=0.4261  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=9.6665  , p=0.3782  , df=9
# likelihood ratio test: chi2=9.5376  , p=0.3892  , df=9
# parameter F test:         F=1.0167  , p=0.4261  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9509  , p=0.4866  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=10.1064 , p=0.4312  , df=10
# likelihood ratio test: chi2=9.9652  , p=0.4436  , df=10
# parameter F test:         F=0.9509  , p=0.4866  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2805  , p=0.5967  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.2829  , p=0.5948  , df=1
# likelihood ratio test: chi2=0.2828  , p=0.5949  , df=1
# parameter F test:         F=0.2805  , p=0.5967  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6938  , p=0.5004  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.4069  , p=0.4949  , df=2
# likelihood ratio test: chi2=1.4042  , p=0.4955  , df=2
# parameter F test:         F=0.6938  , p=0.5004  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9942  , p=0.3956  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.0413  , p=0.3853  , df=3
# likelihood ratio test: chi2=3.0286  , p=0.3872  , df=3
# parameter F test:         F=0.9942  , p=0.3956  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0445  , p=0.3841  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.2850  , p=0.3688  , df=4
# likelihood ratio test: chi2=4.2598  , p=0.3720  , df=4
# parameter F test:         F=1.0445  , p=0.3841  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8990  , p=0.4818  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.6367  , p=0.4618  , df=5
# likelihood ratio test: chi2=4.6071  , p=0.4657  , df=5
# parameter F test:         F=0.8990  , p=0.4818  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8490  , p=0.5329  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=5.2852  , p=0.5078  , df=6
# likelihood ratio test: chi2=5.2467  , p=0.5126  , df=6
# parameter F test:         F=0.8490  , p=0.5329  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0191  , p=0.4174  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.4454  , p=0.3840  , df=7
# likelihood ratio test: chi2=7.3690  , p=0.3915  , df=7
# parameter F test:         F=1.0191  , p=0.4174  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9159  , p=0.5033  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=7.6936  , p=0.4640  , df=8
# likelihood ratio test: chi2=7.6119  , p=0.4723  , df=8
# parameter F test:         F=0.9159  , p=0.5033  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8489  , p=0.5715  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=8.0706  , p=0.5270  , df=9
# likelihood ratio test: chi2=7.9805  , p=0.5361  , df=9
# parameter F test:         F=0.8489  , p=0.5715  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8363  , p=0.5939  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=8.8886  , p=0.5427  , df=10
# likelihood ratio test: chi2=8.7792  , p=0.5532  , df=10
# parameter F test:         F=0.8363  , p=0.5939  , df_denom=334, df_num=10
# ...
# likelihood ratio test: chi2=3.1665  , p=0.5304  , df=4
# parameter F test:         F=0.7753  , p=0.5418  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7209  , p=0.6081  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=3.7183  , p=0.5906  , df=5
# likelihood ratio test: chi2=3.6993  , p=0.5935  , df=5
# parameter F test:         F=0.7209  , p=0.6081  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6179  , p=0.7160  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=3.8467  , p=0.6974  , df=6
# likelihood ratio test: chi2=3.8263  , p=0.7002  , df=6
# parameter F test:         F=0.6179  , p=0.7160  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8601  , p=0.5384  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=6.2838  , p=0.5070  , df=7
# likelihood ratio test: chi2=6.2293  , p=0.5132  , df=7
# parameter F test:         F=0.8601  , p=0.5384  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0962  , p=0.3652  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=9.2083  , p=0.3250  , df=8
# likelihood ratio test: chi2=9.0916  , p=0.3346  , df=8
# parameter F test:         F=1.0962  , p=0.3652  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9778  , p=0.4581  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=9.2960  , p=0.4104  , df=9
# likelihood ratio test: chi2=9.1767  , p=0.4211  , df=9
# parameter F test:         F=0.9778  , p=0.4581  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1629  , p=0.3151  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=12.3602 , p=0.2617  , df=10
# likelihood ratio test: chi2=12.1499 , p=0.2751  , df=10
# parameter F test:         F=1.1629  , p=0.3151  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0008  , p=0.9769  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0008  , p=0.9768  , df=1
# likelihood ratio test: chi2=0.0008  , p=0.9768  , df=1
# parameter F test:         F=0.0008  , p=0.9769  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1376  , p=0.3217  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.3070  , p=0.3155  , df=2
# likelihood ratio test: chi2=2.2997  , p=0.3167  , df=2
# parameter F test:         F=1.1376  , p=0.3217  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0422  , p=0.3739  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.1882  , p=0.3635  , df=3
# likelihood ratio test: chi2=3.1742  , p=0.3655  , df=3
# parameter F test:         F=1.0422  , p=0.3739  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9147  , p=0.4554  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=3.7522  , p=0.4406  , df=4
# likelihood ratio test: chi2=3.7329  , p=0.4434  , df=4
# parameter F test:         F=0.9147  , p=0.4554  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8900  , p=0.4878  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.5904  , p=0.4679  , df=5
# likelihood ratio test: chi2=4.5614  , p=0.4717  , df=5
# parameter F test:         F=0.8900  , p=0.4878  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2903  , p=0.2609  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=8.0328  , p=0.2357  , df=6
# likelihood ratio test: chi2=7.9443  , p=0.2422  , df=6
# parameter F test:         F=1.2903  , p=0.2609  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1591  , p=0.3258  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=8.4683  , p=0.2931  , df=7
# likelihood ratio test: chi2=8.3697  , p=0.3011  , df=7
# parameter F test:         F=1.1591  , p=0.3258  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9241  , p=0.4965  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=7.7622  , p=0.4570  , df=8
# likelihood ratio test: chi2=7.6790  , p=0.4654  , df=8
# parameter F test:         F=0.9241  , p=0.4965  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8355  , p=0.5838  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=7.9430  , p=0.5399  , df=9
# likelihood ratio test: chi2=7.8557  , p=0.5488  , df=9
# parameter F test:         F=0.8355  , p=0.5838  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8992  , p=0.5341  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=9.5577  , p=0.4801  , df=10
# likelihood ratio test: chi2=9.4313  , p=0.4917  , df=10
# parameter F test:         F=0.8992  , p=0.5341  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0150  , p=0.9027  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0151  , p=0.9022  , df=1
# likelihood ratio test: chi2=0.0151  , p=0.9022  , df=1
# parameter F test:         F=0.0150  , p=0.9027  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4823  , p=0.2285  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=3.0060  , p=0.2225  , df=2
# likelihood ratio test: chi2=2.9936  , p=0.2238  , df=2
# parameter F test:         F=1.4823  , p=0.2285  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3262  , p=0.2656  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=4.0570  , p=0.2554  , df=3
# likelihood ratio test: chi2=4.0345  , p=0.2578  , df=3
# parameter F test:         F=1.3262  , p=0.2656  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0573  , p=0.3776  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=4.3375  , p=0.3623  , df=4
# likelihood ratio test: chi2=4.3116  , p=0.3655  , df=4
# parameter F test:         F=1.0573  , p=0.3776  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9271  , p=0.4633  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.7818  , p=0.4431  , df=5
# likelihood ratio test: chi2=4.7503  , p=0.4471  , df=5
# parameter F test:         F=0.9271  , p=0.4633  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0885  , p=0.3688  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=6.7763  , p=0.3420  , df=6
# likelihood ratio test: chi2=6.7131  , p=0.3482  , df=6
# parameter F test:         F=1.0885  , p=0.3688  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0713  , p=0.3815  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=7.8267  , p=0.3481  , df=7
# likelihood ratio test: chi2=7.7424  , p=0.3559  , df=7
# parameter F test:         F=1.0713  , p=0.3815  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9724  , p=0.4573  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=8.1682  , p=0.4172  , df=8
# likelihood ratio test: chi2=8.0762  , p=0.4261  , df=8
# parameter F test:         F=0.9724  , p=0.4573  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8636  , p=0.5581  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=8.2111  , p=0.5130  , df=9
# likelihood ratio test: chi2=8.1178  , p=0.5223  , df=9
# parameter F test:         F=0.8636  , p=0.5581  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9129  , p=0.5213  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=9.7032  , p=0.4669  , df=10
# likelihood ratio test: chi2=9.5730  , p=0.4787  , df=10
# parameter F test:         F=0.9129  , p=0.5213  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1914  , p=0.6620  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.1930  , p=0.6604  , df=1
# likelihood ratio test: chi2=0.1930  , p=0.6604  , df=1
# parameter F test:         F=0.1914  , p=0.6620  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6413  , p=0.5272  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.3006  , p=0.5219  , df=2
# likelihood ratio test: chi2=1.2982  , p=0.5225  , df=2
# parameter F test:         F=0.6413  , p=0.5272  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3531  , p=0.7869  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.0802  , p=0.7819  , df=3
# likelihood ratio test: chi2=1.0786  , p=0.7822  , df=3
# parameter F test:         F=0.3531  , p=0.7869  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3224  , p=0.8629  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=1.3227  , p=0.8575  , df=4
# likelihood ratio test: chi2=1.3202  , p=0.8579  , df=4
# parameter F test:         F=0.3224  , p=0.8629  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5077  , p=0.7704  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.6185  , p=0.7585  , df=5
# likelihood ratio test: chi2=2.6091  , p=0.7600  , df=5
# parameter F test:         F=0.5077  , p=0.7704  , df_denom=349, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5486  , p=0.7710  , df_denom=346, df_num=6
# ssr based chi2 test:   chi2=3.4154  , p=0.7552  , df=6
# likelihood ratio test: chi2=3.3993  , p=0.7573  , df=6
# parameter F test:         F=0.5486  , p=0.7710  , df_denom=346, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7927  , p=0.5938  , df_denom=343, df_num=7
# ssr based chi2 test:   chi2=5.7919  , p=0.5643  , df=7
# likelihood ratio test: chi2=5.7455  , p=0.5698  , df=7
# parameter F test:         F=0.7927  , p=0.5938  , df_denom=343, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6817  , p=0.7077  , df_denom=340, df_num=8
# ssr based chi2 test:   chi2=5.7264  , p=0.6779  , df=8
# likelihood ratio test: chi2=5.6809  , p=0.6829  , df=8
# parameter F test:         F=0.6817  , p=0.7077  , df_denom=340, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5940  , p=0.8020  , df_denom=337, df_num=9
# ssr based chi2 test:   chi2=5.6473  , p=0.7746  , df=9
# likelihood ratio test: chi2=5.6030  , p=0.7789  , df=9
# parameter F test:         F=0.5940  , p=0.8020  , df_denom=337, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5683  , p=0.8396  , df_denom=334, df_num=10
# ssr based chi2 test:   chi2=6.0402  , p=0.8119  , df=10
# likelihood ratio test: chi2=5.9894  , p=0.8162  , df=10
# parameter F test:         F=0.5683  , p=0.8396  , df_denom=334, df_num=10
# Error in Granger test: name 'min_p_veg_to_climate' is not defined
#
# Significant causal relationships for warungkondang:
#                          climate_feature vegetation_stat  max_lag  \
# 0               soil_temperature_level_1   smoothed_mean       10
# 1               soil_temperature_level_2            mean       10
# 2               soil_temperature_level_2   smoothed_mean       10
# 3                total_precipitation_sum   smoothed_mean       10
# 4  surface_solar_radiation_downwards_sum   smoothed_mean       10
# 5        surface_net_solar_radiation_sum   smoothed_mean       10
# 6                  total_evaporation_sum   smoothed_mean       10
# 7                u_component_of_wind_10m             max       10
# 8                u_component_of_wind_10m             std       10
# 9                v_component_of_wind_10m             std       10
#
#    min_p_value causality_direction
# 0     0.030047      granger-causal
# 1     0.034524      granger-causal
# 2     0.018628      granger-causal
# 3     0.025709      granger-causal
# 4     0.019227      granger-causal
# 5     0.019128      granger-causal
# 6     0.030264      granger-causal
# 7     0.048119      granger-causal
# 8     0.031874      granger-causal
# 9     0.029754      granger-causal
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 110
#     107     print("\nAnalysis complete! Visualization files have been saved.")
#     109 if __name__ == "__main__":
# --> 110     main()
#
# Cell In[13], line 105, in main()
#     103 # 3. Correlation heatmaps at different lags
#     104 for lag in [-10, -5, 0, 5, 10]:
# --> 105     plot_correlation_heatmap(results[selected_kec], lag)
#     107 print("\nAnalysis complete! Visualization files have been saved.")
#
# Cell In[9], line 253, in plot_correlation_heatmap(lag_corr_df, lag)
#     246 p_value_pivot = lag_subset.pivot_table(
#     247     index='climate_feature',
#     248     columns='statistic',
#     249     values='p_value'
#     250 )
#     252 plt.figure(figsize=(12, 8))
# --> 253 sns.heatmap(p_value_pivot < 0.05, annot=p_value_pivot, cmap='viridis',
#     254             fmt='.3f', cbar_kws={'label': 'p-value'})
#     256 plt.title(f'P-values Heatmap (Lag = {lag})')
#     257 plt.tight_layout()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/seaborn/matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/seaborn/matrix.py:202, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     200         vmin = np.nanpercentile(calc_data, 2)
#     201     else:
# --> 202         vmin = np.nanmin(calc_data)
#     203 if vmax is None:
#     204     if robust:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gee/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:343, in nanmin(a, axis, out, keepdims, initial, where)
#     338     kwargs['where'] = where
#     340 if type(a) is np.ndarray and a.dtype != np.object_:
#     341     # Fast, but not safe for subclasses of ndarray, or object arrays,
#     342     # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 343     res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     344     if np.isnan(res).any():
#     345         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     346                       stacklevel=2)
#
# ValueError: zero-size array to reduction operation fmin which has no identity
